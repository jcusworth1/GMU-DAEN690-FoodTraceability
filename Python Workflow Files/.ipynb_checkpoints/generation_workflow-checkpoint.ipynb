# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from entity_generation import generate_business_entities
from datetime import datetime, timedelta
from tqdm import tqdm

# %% [markdown]
# ### Load the core data

# %%
ftl_df = pd.read_excel('ftl_items.xlsx', sheet_name='Sheet1')
ftl_df
# Out:
#                      Food              Category Supply_Chain
# 0                cilantro         Herbs (fresh)       Farmed
# 1                 parsley         Herbs (fresh)       Farmed
# 2                   basil         Herbs (fresh)       Farmed
# 3                 arugula  Leafy greens (fresh)       Farmed
# 4               baby leaf  Leafy greens (fresh)       Farmed
# ..                    ...                   ...          ...
# 292           fuji apples                 Fruit       Farmed
# 293   granny smith apples                 Fruit       Farmed
# 294          blackberries                 Fruit       Farmed
# 295           blueberries                 Fruit       Farmed
# 296  red delicious apples                 Fruit       Farmed
#
# [297 rows x 3 columns]

# %%
ftl_df.Category.unique()
# Out:
# array(['Herbs (fresh)', 'Leafy greens (fresh)', 'Cheese', 'Nut butters',
#        'Melons', 'Peppers', 'Sprouts', 'Tropical Tree Fruits', 'Seafood',
#        'Ready-to-eat deli salads\xa0', 'Tomatoes', 'Shell eggs',
#        'Cucumbers (fresh)', 'Fruit'], dtype=object)

# %%
entities_df = generate_business_entities()
entities_df
# Out:
#             businessType         businessName   primaryPhone  \
# 0                   farm  Golden Meadows Farm     9435911493
# 1              packaging         Global Packs   045-557-1012
# 2      landBasedReceiver        Wave Seafoods  (078)487-4539
# 3              processor       Fresh Products     0144192826
# 4     groceryNoTransform           Tasty Shop     6618266301
# ...                  ...                  ...            ...
# 9995          restaurant    Gourmet Brasserie  (644)317-1382
# 9996           packaging      Innovative Pack  (515)110-6274
# 9997  groceryNoTransform       Natural Bazaar     3007165954
# 9998   landBasedReceiver         Sea Seafoods  (572)777-9593
# 9999   landBasedReceiver       Aqua Fisheries     1564471723
#
#                        streetAddress          city state    zip
# 0                 09343 Patricia Via     Ryanshire    VA  97283
# 1               10164 Stephen Avenue  Lake Natasha    CO  69332
# 2                    477 Powell Lane  Port Jessica    DE  87193
# 3               360 Ramsey Underpass  Jacobborough    MP  67259
# 4     070 Jennifer Centers Suite 739    Wilsonview    SD  40480
# ...                              ...           ...   ...    ...
# 9995     9995 Mendez Fields Apt. 200      Choitown    NH  05338
# 9996                 88205 Amy Vista      Emilyton    NV  55633
# 9997   58562 Chavez Tunnel Suite 851    Josephbury    KS  19063
# 9998          0988 Bradford Turnpike    East Jamie    FL  95452
# 9999    59513 Jared Station Apt. 782  Prestonville    TX  31350
#
# [10000 rows x 7 columns]

# %%
entities_df.businessType.unique()
# Out:
# array(['farm', 'packaging', 'landBasedReceiver', 'processor',
#        'groceryNoTransform', 'seafoodFarm', 'distributor', 'restaurant',
#        'grocery', 'wholesaler'], dtype=object)

# %% [markdown]
# # Data Generation Functions

# %% [markdown]
# ### Generate Supply Chain

# %%
def generate_supply_chain(ftl_item):
    #Initialize the supply chain variables
    chain = []

    farm = 'farm'
    field_packed = 'fieldPacked'
    packaging_processor = 'packaging'
    food_processor = 'processor'
    kill = 'stop'
    lbr = 'landBasedReceiver'
    direct_sale = 'directToConsumer'
    seaFarm = 'seafoodFarm'
    agg = 'aggregator'
    rest = 'restaurant'
    grocNoFood = 'groceryNoTransform'
    grocFood = 'grocery'
    dist = 'distributor'
    whole = 'wholesaler'


    #Determine if the food will be an empty node item - do this after Zac sends the rest of the supply chain info

    #Farmed Product Supply Chain Route
    if ftl_item.Supply_Chain.values[0] == 'Farmed':
        chain.append(farm)
        #Determine if field packed or processed
        pack_int = random.randint(0,100)
        if pack_int >= 50:
            chain.append(field_packed)
        else:
            chain.append(packaging_processor)

    #Created Product Supply Chain Route
    elif ftl_item.Supply_Chain.values[0] == 'Created':
        chain.append(food_processor)
        if ftl_item.Category.values[0] == 'Cheese' or ftl_item.Category.values[0] == 'Nut Butters':
            rand = random.randint(0,100)
            if rand > 50:
                chain.append(food_processor)
            #Determine Cheese Continued Manufacturing Route
            if ftl_item.Category.values[0] == 'Nut Butters':
                if rand > 75:
                    chain.append(food_processor)
                else:
                    chain.append(kill)
            else:
                chain.append(kill)

    #Fish Supply Chain Route
    elif ftl_item.Category.values[0] == 'Seafood':

        #Caught fish Supply Chain Route
        if ftl_item.Supply_Chain.values[0] == 'Caught':
            chain.append(lbr)
            #Fill in the rest here

        #Aquaculture Supply Chain Route
        if ftl_item.Supply_Chain.values[0] == 'Aquaculture':
            chain.append(seaFarm)

        #Determine if the food will go to an aggregator
        rand = random.randint(0,100)
        if rand > 50:
            chain.append(agg)

        #Determine if the food goes through a kill step or continues to get processed
        chain.append(food_processor)

        rand = random.randint(0,100)
        if rand > 50:
            chain.append(food_processor)

            if rand > 75:
                chain.append(food_processor)

            else:
                chain.append(kill)

        else:
            chain.append(kill)

            
    if chain[-1] != kill:
        #Initialize the retail options
        retail_options = [rest, grocFood, grocNoFood]
        
        #Sale Route - this will be the same for every food
        sale_int = random.randint(0,100)
        #Determine if it is sold direct-to-consumer
        if sale_int <= 7:
            sale_int = random.randint(0,100)
            if sale_int <= 27:
                chain.append(direct_sale)
            else:
                chain.append(random.choice(retail_options))
        else:
        
            #If not, do the indirect sales route
            route_1 = random.randint(0,100)
            if route_1 <= 50:
                chain.append(dist)
                route_2 = random.randint(0,100)
                if route_2 <= 20:
                    chain.append(whole)
                else:
                    chain.append(random.choice(retail_options))
                
            else:
                chain.append(food_processor)
                route_2 = random.randint(0,100)
                if route_2 <= 50:
                    chain.append(dist)
                    route_2 = random.randint(0,100)
                    if route_2 <= 20:
                        chain.append(whole)
                    else:
                        chain.append(random.choice(retail_options))
                else:
                    route_2 = random.randint(0,100)
                    if route_2 <= 20:
                        chain.append(whole)
                    else:
                        chain.append(random.choice(retail_options))
            if chain[-1] == whole:
                route_int = random.randint(0,100)
                if route_int < 50:
                    chain.append(random.choice(retail_options))

    return chain

# %% [markdown]
# ### CTE Generation Functions

# %%
field_name_list = ['Field A-08',
              'Field A-09',
              'Field B-09',
              'Field A-10',
              'Field C-10',
              'Field G-20',
              'Field V-09',
              'Bed 34',
              'Acre P30',
              'Acre P23',
              'Walker Field',
              'Garden Bed',
              'Rose Garden',
              'Hillock Field',
              'Grasslands',
              'Ranch P20',
              'Barn F 30'
              ]

container_name_list = ['Pond',
                       'Pool',
                       'Tank',
                       'Cage']

def harvesting_cte(fake, ftl_item, farm, next_entity, field_name_list = field_name_list, container_name_list=container_name_list):
    #Determine date
    start_date = datetime.strptime('2022-01-01', '%Y-%m-%d')
    end_date = datetime.strptime('2023-06-01','%Y-%m-%d')
    date_harvested = str(fake.date_between_dates(date_start=start_date, date_end=end_date))

    data_submitter = farm.businessName
    food_name = ftl_item.Food.values[0]
    quantity = fake.random_int(min=1, max=1000)
    recipient = next_entity.businessName
    unit_of_measure = fake.random_element(elements=('kg', 'g', 'lbs', 'Dozen'))
    farm_name = farm.businessName
    phone_number = farm.primaryPhone

    #Determine what field or container was used
    if ftl_item.Supply_Chain.values[0] == 'Farmed':
        field_name = random.choice(field_name_list)
        container = 'n/a'
    elif ftl_item.Supply_Chain.values[0] == 'Aquaculture':
        field_name = 'n/a'
        container = random.choice(container_name_list) + ' ' + str(random.randint(1,10))
    
    #Need to add location description of farm where it was harvested
    harvesting_info = {
        'dataSubmitter': data_submitter,
        'recipient' : recipient,
        'commodity': food_name,
        'quantity' : quantity,
        'unitOfMeasure' : unit_of_measure,
        'farmName' : farm_name,
        'fieldName' : field_name,
        'containerName' : container,
        'cteDate' : date_harvested,
        'phoneNumber' : phone_number    
    }

    return harvesting_info

# %%
def cooling_cte(harvesting_info, ftl_item, facility, next_entity):

    data_submitter = facility.businessName
    food_name = ftl_item.Food.values[0]
    quantity = harvesting_info['quantity']
    recipient = next_entity.businessName
    unit_of_measure = harvesting_info['unitOfMeasure']
    farm_name = harvesting_info['dataSubmitter']
    cooler_location = facility.businessName
    date_cooled = harvesting_info['cteDate']
    phone_number = facility.primaryPhone
    
    #Need to add location description of farm where it was harvested
    cooling_info = {
        'dataSubmitter': data_submitter,
        'recipient' : recipient,
        'commodity': food_name,
        'quantity' : quantity,
        'unitOfMeasure' : unit_of_measure,
        'coolerLocation' : cooler_location,
        'cteDate' : date_cooled,
        'harvesterName' : farm_name,
        'phoneNumber' : phone_number    
    }

    return cooling_info

# %%
def packaging_cte(fake, harvesting_info, cooling_info, ftl_item, facility):
    # List of packaging types
    packaging_type = ['Box', 'Bag', 'Crate', 'Can', 'Bottle', 'Jar', 'Pouch', 'Carton']

    data_submitter = facility.businessName
    package_type = random.choice(packaging_type)
    quantity = fake.random_int(min=1, max=1000)
    unit_of_measure = fake.random_element(elements=('kg', 'g', 'lbs', 'Dozen'))
    packaging_date = str((datetime.strptime(cooling_info['cteDate'], '%Y-%m-%d') + timedelta(days=random.randint(0,3))).date())
    traceability_lot_code = fake.bothify(text='??-####', letters='ABCDEFGHIJKLMNOPQRSTUVWXYZ')
    product_description = harvesting_info['dataSubmitter'] + ' ' + harvesting_info['commodity'] + ', ' + str(fake.random_int(min=1, max= 50)) + unit_of_measure + ' case'


    packaging_info = {
        'dataSubmitter': data_submitter,
        'commodity':ftl_item.Food.values[0],
        'dateFoodReceived' : packaging_date,
        'quantityReceived':harvesting_info['quantity'],
        'harvestingLocation':harvesting_info['dataSubmitter'],
        'harvestedField':harvesting_info['fieldName'], #For produce
        'harvestedContainer':harvesting_info['containerName'], #For Aquaculture
        'harvestedPhoneNumber':harvesting_info['phoneNumber'],
        'dateHarvested':harvesting_info['cteDate'],
        'coolingLocation':cooling_info['dataSubmitter'],
        'dateOfCooling':cooling_info['cteDate'],
        'traceabilityLotCode': traceability_lot_code,
        'productDescription':product_description,
        'quantity' : quantity,
        'unitOfMeasure':cooling_info['unitOfMeasure'],
        'packageType': package_type,
        'traceabilityLotCodeSourceLocation':facility.businessName,
        'cteDate' : packaging_date,
        'referenceDocumentTypeNumber': 'IP WO ' + str(random.randint(10000,50000)) 
    }

    return packaging_info

# %%
def shipping_cte(previous_cte, next_entity, facility):

    shippedDate = str((datetime.strptime(previous_cte['cteDate'], '%Y-%m-%d') + timedelta(days=random.randint(0,3))).date())
    productDescription = previous_cte['productDescription']

    shipping_info = {
        'dataSubmitter': facility.businessName,
        'traceabilityLotCode': previous_cte['traceabilityLotCode'],
        'quantity': previous_cte['quantity'],
        'unitOfMeasure':previous_cte['unitOfMeasure'],
        'productDescription': productDescription,
        'subsequentLocation': next_entity.businessName,
        'previousSourceLocation': previous_cte['dataSubmitter'],
        'cteDate': shippedDate,
        'traceabilityLotCodeSourceLocation': previous_cte['traceabilityLotCodeSourceLocation'],
        'referenceDocumentTypeNumber': 'BOL ' + str(random.randint(10000,50000)) 
    }

    return shipping_info

# %%
def receiving_cte(previous_cte, facility):
    receivingDate = str((datetime.strptime(previous_cte['cteDate'], '%Y-%m-%d') + timedelta(days=random.randint(0,3))).date())

    receiving_info = {
        'dataSubmitter': facility.businessName,
        'traceabilityLotCode': previous_cte['traceabilityLotCode'],
        'quantity': previous_cte['quantity'],
        'unitOfMeasure':previous_cte['unitOfMeasure'],
        'productDescription': previous_cte['productDescription'],
        'previousSourceLocation': previous_cte['dataSubmitter'],
        'receivingLocation': facility.businessName,
        'cteDate': receivingDate,
        'traceabilityLotCodeSourceLocation': previous_cte['traceabilityLotCodeSourceLocation'],
        'referenceDocumentTypeNumber': 'BOL ' + str(random.randint(10000,50000))
    }

    return receiving_info

# %%
#New transformation
def transformation_cte(previous_cte, ftl_item, facility):
    
    #creating universal variables
    quantity = random.randint(1,1000)
    quantityUsed = random.randint(quantity,2000)
    unitOfMeasure = random.choice(['cases', 'oz', 'lbs', 'kg'])
    traceabilityLotCode = fake.bothify(text='??-####', letters='ABCDEFGHIJKLMNOPQRSTUVWXYZ')

    category = ftl_item.Category.values[0]
    
    #generating transformation date
    try: 
        transformedDate = str((datetime.strptime(previous_cte['cteDate'], '%Y-%m-%d') + timedelta(days=random.randint(0,3))).date())
        productDescription = previous_cte['productDescription']
        oldTraceabilityLotCode = previous_cte['traceabilityLotCode']
        oldProductDescription = previous_cte['productDescription']
        previousUnitOfMeasure = previous_cte['unitOfMeasure']

        
    except:
        start_date = datetime.strptime('01/01/2020', '%m/%d/%Y')
        end_date = datetime.now()
        transformedDate = str(fake.date_between(start_date=start_date, end_date=end_date))
        oldProductDescription = ftl_item.Food.values[0]
        oldTraceabilityLotCode = traceabilityLotCode
        traceabilityLotCode = fake.bothify(text='??-####', letters='ABCDEFGHIJKLMNOPQRSTUVWXYZ')
        productDescription = ftl_item.Food.values[0]
        previousUnitOfMeasure = random.choice(['cases', 'oz', 'lbs', 'kg'])
        
    
    #transforming foods
    #fruit
    if category in ftl_df.loc[ftl_df['Category'] == 'Fruit', 'Food'].tolist(): 
        productDescription = "Fresh Cut " + productDescription
    elif category in ftl_df.loc[ftl_df['Category'] == 'Melons', 'Food'].tolist(): 
        productDescription = "Fresh Cut " + productDescription
    elif category in ftl_df.loc[ftl_df['Category'] == 'Tropical Tree Fruits', 'Food'].tolist(): 
        productDescription = "Fresh Cut " + productDescription
    
    #nut butter
    elif category in ftl_df.loc[ftl_df['Category'] == 'Nut Butter', 'Food'].tolist():
        productDescription = productDescription + " Butter"
   
    #salads
    elif category in ftl_df.loc[ftl_df['Category'] == 'Shell Eggs', 'Food'].tolist():
        productDescription = "Egg Salad"
    elif category in ftl_df.loc[ftl_df['Category'] == 'Crustaceans', 'Food'].tolist(): 
        productDescription = "Seafood Salad"
    elif category in ftl_df.loc[ftl_df['Category'] == 'Leafy greens (fresh)', 'Food'].tolist(): 
        productDescription = "Pasta Salad"
    elif category in ftl_df.loc[ftl_df['Category'] == 'Peppers', 'Food'].tolist(): 
        productDescription = "Pasta Salad"
    elif category in ftl_df.loc[ftl_df['Category'] == 'Tomatoes', 'Food'].tolist(): 
        productDescription = "Pasta Salad"
    elif category in ftl_df.loc[ftl_df['Category'] == 'Cucumbers (fresh)', 'Food'].tolist(): 
        productDescription = "Pasta Salad"
    elif category in ftl_df.loc[ftl_df['Category'] == 'Herbs (fresh)', 'Food'].tolist(): 
        productDescription = random.choice(['Egg Salad','Potato Salad','Pasta Salad','Seafood Salad']) 
    
    #fish
    elif category in ftl_df.loc[ftl_df['Category'] == 'Seafood', 'Food'].tolist():
        if random.randint(0,100) < 15:
            productDescription = "Smoked " + productDescription 
        else:
            productDescription = productDescription + "Filet"
    
    #remaining foods
    else:
        productDescription = productDescription
    
    transformation_info = {
        'dataSubmitter': facility.businessName,
        'oldTraceabilityLotCode': oldTraceabilityLotCode,
        'oldProductDescription':oldProductDescription,
        'quantityUsed':quantityUsed,
        'previousUnitOfMeasure':previousUnitOfMeasure,
        'traceabilityLotCode': traceabilityLotCode,
        'traceabilityLotCodeSourceLocation': facility.businessName,
        'cteDate': transformedDate,
        'productDescription': productDescription,
        'quantity': quantity,
        'unitOfMeasure': unitOfMeasure,
        'referenceDocumentTypeNumber': 'BOL ' + str(random.randint(10000,50000))
    }

    return transformation_info

# %%
def first_land_based_receiver_cte(fake, ftl_item, facility):
    #Determine the dates of harvest and landing
    start_date = datetime.strptime('2022-01-01', '%Y-%m-%d')
    end_date = datetime.strptime('2023-06-01','%Y-%m-%d')
    firstHarvestDate = fake.date_between_dates(date_start=start_date, date_end=end_date)
    secondHarvestDate = firstHarvestDate + timedelta(days=random.randint(2,10))

    dateLanded = secondHarvestDate + timedelta(days=random.randint(1,3))

    #Determine Harvest Location
    secondLine = 'Major Fishing Area ' + str(random.randint(1,10))
    thirdLine = random.choice(['Northern', 'Southern', 'Central']) + ' ' + random.choice(['Pacific','Atlantic']) 

    harvestDateAndLocation = str(firstHarvestDate) + ' - ' + str(secondHarvestDate) + '\n' + secondLine + '\n' + thirdLine

    #Determine the quantity and unit of measure
    quantity = random.randint(20,1000)
    unitOfMeasure = random.choice(['kg', 'lb'])

    #Determine the traceability lot code
    traceability_lot_code = fake.bothify(text='??-####', letters='ABCDEFGHIJKLMNOPQRSTUVWXYZ')

    first_land_based_receiver_info = {
        'dataSubmitter':facility.businessName,
        'traceabilityLotCode':traceability_lot_code,
        'productDescription':ftl_item.Food.values[0],
        'quantity':quantity,
        'unitOfMeasure':unitOfMeasure,
        'harvestDateAndLocation':harvestDateAndLocation,
        'traceabilityLotCodeSourceLocation':facility.businessName,
        'cteDate':str(dateLanded),
        'referenceDocumentTypeNumber': 'Landing Record: ' + str(random.randint(10000,50000))
    }

    return first_land_based_receiver_info

# %% [markdown]
# ### Supply Chain Functions

# %%
def farm_function(fake, ftl_item, sc, entities, previous_cte, index):
    farm = entities.iloc[index]
    packaged_type = sc[sc.index('farm') + 1]

    try:
        next_entity = entities.iloc[index+1]

    except:
        next_entity = farm

    #Initialize the CTEs for the farm
    ctes = {}

    #Determine what the next entity is for the KDEs that happen on the farm
    if packaged_type == 'fieldPacked':
        ctes['harvesting'] = harvesting_cte(fake, ftl_item, farm, farm)
        ctes['cooling'] = cooling_cte(ctes['harvesting'], ftl_item, farm, farm)
        ctes['initialPackaging'] = packaging_cte(fake,ctes['harvesting'],ctes['cooling'],ftl_item,farm)
        ctes['shipping'] = shipping_cte(ctes['initialPackaging'],next_entity,farm)
    elif packaged_type == 'packaging':
        ctes['harvesting'] = harvesting_cte(fake, ftl_item, farm, next_entity)

    return ctes

# %%
def initial_fish_function(fake, ftl_item, sc, entities, previous_cte, index):
    category = ftl_item.Supply_Chain.values[0]

    ctes={}
    #Aquaculture route
    if category == 'Aquaculture':
        facility = entities.iloc[index]
        next_entity=facility
        ctes['harvesting'] = harvesting_cte(fake, ftl_item, facility, next_entity)
        ctes['cooling'] = cooling_cte(ctes['harvesting'], ftl_item, facility, next_entity)
        ctes['initialPackaging'] = packaging_cte(fake,ctes['harvesting'],ctes['cooling'],ftl_item,facility)

    #Wild Caught Route
    elif category =='Caught':
        facility = entities.iloc[index]
        ctes['firstLandBasedReceiving'] = first_land_based_receiver_cte(fake, ftl_item, facility)

    #Ship to the next entity
    last_cte = list(ctes.keys())[-1]
    ctes['shipping'] = shipping_cte(ctes[last_cte],next_entity=entities.iloc[index+1],facility=facility)

    return ctes

# %%
def processing_plant_function(fake, ftl_item, sc, entities, previous_cte, index):

    facility = entities.iloc[index]
    try:
        next_entity = entities.iloc[index+1]
        kill = 0
    except:
        kill = 1

    # Initialize the CTEs for the processing plant
    ctes = {}

    #The path if it is a created product and the first step in the supply chain
    if index == 0:
        ctes['transformation'] = transformation_cte(previous_cte,ftl_item,facility)

    #The path if it is not the first step in the supply chain
    else:

        ctes['receiving'] = receiving_cte(previous_cte, facility)
        ctes['transformation'] = transformation_cte(ctes['receiving'], ftl_item, facility)

    #Determine if a kill step had happened, if not proceed
    if kill == 0:
        ctes['shipping'] = shipping_cte(ctes['transformation'], next_entity, facility)
    
    return ctes

# %%
def coolingpacking_function(fake, ftl_item, sc, entities, previous_cte, index):
    # Initialize the CTEs for the offsite cooling and packing facility
    facility = entities.iloc[index]

    try:
        next_entity = entities.iloc[index+1]
        kill = 0
    except:
        next_entity = 0
        kill = 1

    ctes = {}

    ctes['cooling'] = cooling_cte(previous_cte, ftl_item, facility, facility)
    ctes['initialPackaging'] = packaging_cte(fake,previous_cte,ctes['cooling'],ftl_item, facility)

    if kill == 0:
        ctes['shipping'] = shipping_cte(ctes['initialPackaging'], next_entity=next_entity, facility=facility)

    return ctes

# %%
def distributor_function(fake, ftl_item, sc, entities, previous_cte, index):
    facility = entities.iloc[index]
    next_entity = entities.iloc[index+1]

    # Initialize the CTEs for the processing plant
    ctes = {}

    ctes['receiving'] = receiving_cte(previous_cte, facility)

    ctes['shipping'] = shipping_cte(ctes['receiving'], next_entity, facility)

    return ctes

# %%
def wholesaler_function(fake, ftl_item, sc, entities, previous_cte, index):
    facility = entities.iloc[index]

    try:
        next_entity = entities.iloc[index+1]
        kill = 0

    except:
        kill = 1

    # Initialize the CTEs for the processing plant
    ctes = {}

    ctes['receiving'] = receiving_cte(previous_cte, facility)

    #Determine if there is going to be a transformation or not
    if random.randint(0,100) > 50:
        ctes['transformation'] = transformation_cte(ctes['receiving'], ftl_item, facility)

    if kill == 0:
        last_cte = list(ctes.keys())[-1]
        ctes['shipping'] = shipping_cte(ctes[last_cte], next_entity, facility)

    return ctes

# %%
def grocery_function(fake, ftl_item, sc, entities, previous_cte, index):
    facility = entities.iloc[index]

    # Initialize the CTEs for the processing plant
    ctes = {}

    ctes['receiving'] = receiving_cte(previous_cte, facility)

    #Determine if there is going to be a transformation or not
    if random.randint(0,100) < 10:
        ctes['transformation'] = transformation_cte(ctes['receiving'], ftl_item, facility)

    return ctes

# %%
def restaurant_function(fake, ftl_item, sc, entities, previous_cte, index):
    facility = entities.iloc[index]

    # Initialize the CTEs for the processing plant
    ctes = {}

    ctes['receiving'] = receiving_cte(previous_cte, facility)

    #Determine if there is going to be a transformation or not
    if random.randint(0,100) > 95:
        ctes['transformation'] = transformation_cte(ctes['receiving'], ftl_item, facility)

    return ctes

# %%
def grocery_no_transform_function(fake, ftl_item, sc, entities, previous_cte, index):
    facility = entities.iloc[index]

    # Initialize the CTEs for the processing plant
    ctes = {}

    ctes['receiving'] = receiving_cte(previous_cte, facility)

    return ctes

# %% [markdown]
# # Generate the Data

# %%
def generate_data(ftl_df, entities_df, n=10000):
    fake = Faker()

    #Create a dictionary of the functions so that they can be called in the supply chain based on the type of entity
    functions_dict = {
        'farm':farm_function,
        'wholesaler':wholesaler_function,
        'grocery':grocery_function,
        'groceryNoTransform':grocery_no_transform_function,
        'distributor':distributor_function,
        'packaging':coolingpacking_function,
        'restaurant':restaurant_function,
        'processor':processing_plant_function,
        'landBasedReceiver':initial_fish_function,
        'seafoodFarm':initial_fish_function
    }

    all_ctes = []
    for _ in tqdm(range(n)):
        #Randomly select a food item and generate the supply chain
        food_item = ftl_df.sample()
        sc = generate_supply_chain(food_item)

        #Determine the entities for the supply chain
        indexes = []
        for entity_type in sc:
            try:
                entity = entities_df[entities_df.businessType == entity_type].sample().index.values[0]
                indexes.append(entity)
            except:
                pass

        entities = entities_df.iloc[indexes].reset_index(drop=True)

        #Run the function for each entity in the supply chain
        #Note: the input for each function will be (fake, food_item, sc, entities, previous_cte, index)
        #A standardized input makes it easy to iterate through and call each function
        #In plain language, it is calling an instance of faker, the current food_item, the supply chain, the entities in the supply chain, the most recent CTE, and the index
        ctes = []
        for index in entities.index:
            try:
                previous_cte_name = list(ctes[-1].keys())[-1]
                previous_cte = ctes[-1][previous_cte_name]
            except:
                previous_cte = []

            ctes.append(functions_dict[entities.iloc[index].businessType](fake, food_item, sc, entities,previous_cte,index))
        
            

        all_ctes.extend(ctes)

    return all_ctes

# %%
data = generate_data(ftl_df, entities_df)
# Out:
# 100%|██████████| 10000/10000 [01:22<00:00, 120.59it/s]
# CPU times: user 1min 21s, sys: 1.33 s, total: 1min 23s
# Wall time: 1min 23s

# %%
data
# Out:
# [{'harvesting': {'dataSubmitter': 'Green Fields Farm',
#    'recipient': 'Advanced Box',
#    'commodity': 'strawberries',
#    'quantity': 419,
#    'unitOfMeasure': 'kg',
#    'farmName': 'Green Fields Farm',
#    'fieldName': 'Garden Bed',
#    'containerName': 'n/a',
#    'cteDate': '2022-04-04',
#    'phoneNumber': '230-500-2275'}},
#  {'cooling': {'dataSubmitter': 'Advanced Box',
#    'recipient': 'Advanced Box',
#    'commodity': 'strawberries',
#    'quantity': 419,
#    'unitOfMeasure': 'kg',
#    'coolerLocation': 'Advanced Box',
#    'cteDate': '2022-04-04',
#    'harvesterName': 'Green Fields Farm',
#    'phoneNumber': '(094)559-3614'},
#   'initialPackaging': {'dataSubmitter': 'Advanced Box',
#    'commodity': 'strawberries',
#    'dateFoodReceived': '2022-04-07',
#    'quantityReceived': 419,
#    'harvestingLocation': 'Green Fields Farm',
#    'harvestedField': 'Garden Bed',
#    'harvestedContainer': 'n/a',
#    'harvestedPhoneNumber': '230-500-2275',
#    'dateHarvested': '2022-04-04',
#    'coolingLocation': 'Advanced Box',
#    'dateOfCooling': '2022-04-04',
#    'traceabilityLotCode': 'ZU-3590',
#    'productDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'quantity': 986,
#    'unitOfMeasure': 'kg',
#    'packageType': 'Crate',
#    'traceabilityLotCodeSourceLocation': 'Advanced Box',
#    'cteDate': '2022-04-07',
#    'referenceDocumentTypeNumber': 'IP WO 43747'},
#   'shipping': {'dataSubmitter': 'Advanced Box',
#    'traceabilityLotCode': 'ZU-3590',
#    'quantity': 986,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'subsequentLocation': 'Premium Industries',
#    'previousSourceLocation': 'Advanced Box',
#    'cteDate': '2022-04-09',
#    'traceabilityLotCodeSourceLocation': 'Advanced Box',
#    'referenceDocumentTypeNumber': 'BOL 42938'}},
#  {'receiving': {'dataSubmitter': 'Premium Industries',
#    'traceabilityLotCode': 'ZU-3590',
#    'quantity': 986,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'previousSourceLocation': 'Advanced Box',
#    'receivingLocation': 'Premium Industries',
#    'cteDate': '2022-04-12',
#    'traceabilityLotCodeSourceLocation': 'Advanced Box',
#    'referenceDocumentTypeNumber': 'BOL 24491'},
#   'transformation': {'dataSubmitter': 'Premium Industries',
#    'oldTraceabilityLotCode': 'ZU-3590',
#    'oldProductDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'quantityUsed': 595,
#    'previousUnitOfMeasure': 'kg',
#    'traceabilityLotCode': 'PY-1628',
#    'traceabilityLotCodeSourceLocation': 'Premium Industries',
#    'cteDate': '2022-04-15',
#    'productDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'quantity': 279,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 46273'},
#   'shipping': {'dataSubmitter': 'Premium Industries',
#    'traceabilityLotCode': 'PY-1628',
#    'quantity': 279,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'subsequentLocation': 'Natural Outlet',
#    'previousSourceLocation': 'Premium Industries',
#    'cteDate': '2022-04-17',
#    'traceabilityLotCodeSourceLocation': 'Premium Industries',
#    'referenceDocumentTypeNumber': 'BOL 39845'}},
#  {'receiving': {'dataSubmitter': 'Natural Outlet',
#    'traceabilityLotCode': 'PY-1628',
#    'quantity': 279,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'previousSourceLocation': 'Premium Industries',
#    'receivingLocation': 'Natural Outlet',
#    'cteDate': '2022-04-19',
#    'traceabilityLotCodeSourceLocation': 'Premium Industries',
#    'referenceDocumentTypeNumber': 'BOL 11225'},
#   'transformation': {'dataSubmitter': 'Natural Outlet',
#    'oldTraceabilityLotCode': 'PY-1628',
#    'oldProductDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'quantityUsed': 1337,
#    'previousUnitOfMeasure': 'cases',
#    'traceabilityLotCode': 'GH-6352',
#    'traceabilityLotCodeSourceLocation': 'Natural Outlet',
#    'cteDate': '2022-04-19',
#    'productDescription': 'Green Fields Farm strawberries, 29lbs case',
#    'quantity': 86,
#    'unitOfMeasure': 'oz',
#    'referenceDocumentTypeNumber': 'BOL 27986'}},
#  {'transformation': {'dataSubmitter': 'Innovative Products',
#    'oldTraceabilityLotCode': 'RE-0367',
#    'oldProductDescription': 'eggs',
#    'quantityUsed': 1170,
#    'previousUnitOfMeasure': 'oz',
#    'traceabilityLotCode': 'MX-8119',
#    'traceabilityLotCodeSourceLocation': 'Innovative Products',
#    'cteDate': '2021-07-12',
#    'productDescription': 'eggs',
#    'quantity': 641,
#    'unitOfMeasure': 'oz',
#    'referenceDocumentTypeNumber': 'BOL 14969'},
#   'shipping': {'dataSubmitter': 'Innovative Products',
#    'traceabilityLotCode': 'MX-8119',
#    'quantity': 641,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'eggs',
#    'subsequentLocation': 'Healthy Products',
#    'previousSourceLocation': 'Innovative Products',
#    'cteDate': '2021-07-12',
#    'traceabilityLotCodeSourceLocation': 'Innovative Products',
#    'referenceDocumentTypeNumber': 'BOL 17539'}},
#  {'receiving': {'dataSubmitter': 'Healthy Products',
#    'traceabilityLotCode': 'MX-8119',
#    'quantity': 641,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'eggs',
#    'previousSourceLocation': 'Innovative Products',
#    'receivingLocation': 'Healthy Products',
#    'cteDate': '2021-07-14',
#    'traceabilityLotCodeSourceLocation': 'Innovative Products',
#    'referenceDocumentTypeNumber': 'BOL 12666'},
#   'transformation': {'dataSubmitter': 'Healthy Products',
#    'oldTraceabilityLotCode': 'MX-8119',
#    'oldProductDescription': 'eggs',
#    'quantityUsed': 1240,
#    'previousUnitOfMeasure': 'oz',
#    'traceabilityLotCode': 'PH-2928',
#    'traceabilityLotCodeSourceLocation': 'Healthy Products',
#    'cteDate': '2021-07-16',
#    'productDescription': 'eggs',
#    'quantity': 551,
#    'unitOfMeasure': 'lbs',
#    'referenceDocumentTypeNumber': 'BOL 36390'},
#   'shipping': {'dataSubmitter': 'Healthy Products',
#    'traceabilityLotCode': 'PH-2928',
#    'quantity': 551,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'eggs',
#    'subsequentLocation': 'Fine Exim',
#    'previousSourceLocation': 'Healthy Products',
#    'cteDate': '2021-07-17',
#    'traceabilityLotCodeSourceLocation': 'Healthy Products',
#    'referenceDocumentTypeNumber': 'BOL 38796'}},
#  {'receiving': {'dataSubmitter': 'Fine Exim',
#    'traceabilityLotCode': 'PH-2928',
#    'quantity': 551,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'eggs',
#    'previousSourceLocation': 'Healthy Products',
#    'receivingLocation': 'Fine Exim',
#    'cteDate': '2021-07-18',
#    'traceabilityLotCodeSourceLocation': 'Healthy Products',
#    'referenceDocumentTypeNumber': 'BOL 41125'},
#   'shipping': {'dataSubmitter': 'Fine Exim',
#    'traceabilityLotCode': 'PH-2928',
#    'quantity': 551,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'eggs',
#    'subsequentLocation': 'Gourmet Distributors',
#    'previousSourceLocation': 'Fine Exim',
#    'cteDate': '2021-07-19',
#    'traceabilityLotCodeSourceLocation': 'Healthy Products',
#    'referenceDocumentTypeNumber': 'BOL 34170'}},
#  {'receiving': {'dataSubmitter': 'Gourmet Distributors',
#    'traceabilityLotCode': 'PH-2928',
#    'quantity': 551,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'eggs',
#    'previousSourceLocation': 'Fine Exim',
#    'receivingLocation': 'Gourmet Distributors',
#    'cteDate': '2021-07-22',
#    'traceabilityLotCodeSourceLocation': 'Healthy Products',
#    'referenceDocumentTypeNumber': 'BOL 14034'}},
#  {'harvesting': {'dataSubmitter': 'Sea Aquaculture',
#    'recipient': 'Sea Aquaculture',
#    'commodity': 'clams',
#    'quantity': 273,
#    'unitOfMeasure': 'Dozen',
#    'farmName': 'Sea Aquaculture',
#    'fieldName': 'n/a',
#    'containerName': 'Cage 8',
#    'cteDate': '2022-03-27',
#    'phoneNumber': '(735)866-9562'},
#   'cooling': {'dataSubmitter': 'Sea Aquaculture',
#    'recipient': 'Sea Aquaculture',
#    'commodity': 'clams',
#    'quantity': 273,
#    'unitOfMeasure': 'Dozen',
#    'coolerLocation': 'Sea Aquaculture',
#    'cteDate': '2022-03-27',
#    'harvesterName': 'Sea Aquaculture',
#    'phoneNumber': '(735)866-9562'},
#   'initialPackaging': {'dataSubmitter': 'Sea Aquaculture',
#    'commodity': 'clams',
#    'dateFoodReceived': '2022-03-29',
#    'quantityReceived': 273,
#    'harvestingLocation': 'Sea Aquaculture',
#    'harvestedField': 'n/a',
#    'harvestedContainer': 'Cage 8',
#    'harvestedPhoneNumber': '(735)866-9562',
#    'dateHarvested': '2022-03-27',
#    'coolingLocation': 'Sea Aquaculture',
#    'dateOfCooling': '2022-03-27',
#    'traceabilityLotCode': 'HV-3398',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantity': 252,
#    'unitOfMeasure': 'Dozen',
#    'packageType': 'Carton',
#    'traceabilityLotCodeSourceLocation': 'Sea Aquaculture',
#    'cteDate': '2022-03-29',
#    'referenceDocumentTypeNumber': 'IP WO 25528'},
#   'shipping': {'dataSubmitter': 'Sea Aquaculture',
#    'traceabilityLotCode': 'HV-3398',
#    'quantity': 252,
#    'unitOfMeasure': 'Dozen',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'subsequentLocation': 'Global Foods',
#    'previousSourceLocation': 'Sea Aquaculture',
#    'cteDate': '2022-03-31',
#    'traceabilityLotCodeSourceLocation': 'Sea Aquaculture',
#    'referenceDocumentTypeNumber': 'BOL 45625'}},
#  {'receiving': {'dataSubmitter': 'Global Foods',
#    'traceabilityLotCode': 'HV-3398',
#    'quantity': 252,
#    'unitOfMeasure': 'Dozen',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'previousSourceLocation': 'Sea Aquaculture',
#    'receivingLocation': 'Global Foods',
#    'cteDate': '2022-03-31',
#    'traceabilityLotCodeSourceLocation': 'Sea Aquaculture',
#    'referenceDocumentTypeNumber': 'BOL 23119'},
#   'transformation': {'dataSubmitter': 'Global Foods',
#    'oldTraceabilityLotCode': 'HV-3398',
#    'oldProductDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantityUsed': 954,
#    'previousUnitOfMeasure': 'Dozen',
#    'traceabilityLotCode': 'II-8700',
#    'traceabilityLotCodeSourceLocation': 'Global Foods',
#    'cteDate': '2022-04-02',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantity': 860,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 10969'},
#   'shipping': {'dataSubmitter': 'Global Foods',
#    'traceabilityLotCode': 'II-8700',
#    'quantity': 860,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'subsequentLocation': 'Natural Processing',
#    'previousSourceLocation': 'Global Foods',
#    'cteDate': '2022-04-02',
#    'traceabilityLotCodeSourceLocation': 'Global Foods',
#    'referenceDocumentTypeNumber': 'BOL 41046'}},
#  {'receiving': {'dataSubmitter': 'Natural Processing',
#    'traceabilityLotCode': 'II-8700',
#    'quantity': 860,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'previousSourceLocation': 'Global Foods',
#    'receivingLocation': 'Natural Processing',
#    'cteDate': '2022-04-02',
#    'traceabilityLotCodeSourceLocation': 'Global Foods',
#    'referenceDocumentTypeNumber': 'BOL 33343'},
#   'transformation': {'dataSubmitter': 'Natural Processing',
#    'oldTraceabilityLotCode': 'II-8700',
#    'oldProductDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantityUsed': 700,
#    'previousUnitOfMeasure': 'cases',
#    'traceabilityLotCode': 'OO-4264',
#    'traceabilityLotCodeSourceLocation': 'Natural Processing',
#    'cteDate': '2022-04-05',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantity': 392,
#    'unitOfMeasure': 'kg',
#    'referenceDocumentTypeNumber': 'BOL 22087'},
#   'shipping': {'dataSubmitter': 'Natural Processing',
#    'traceabilityLotCode': 'OO-4264',
#    'quantity': 392,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'subsequentLocation': 'Natural Processing',
#    'previousSourceLocation': 'Natural Processing',
#    'cteDate': '2022-04-06',
#    'traceabilityLotCodeSourceLocation': 'Natural Processing',
#    'referenceDocumentTypeNumber': 'BOL 17723'}},
#  {'receiving': {'dataSubmitter': 'Natural Processing',
#    'traceabilityLotCode': 'OO-4264',
#    'quantity': 392,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'previousSourceLocation': 'Natural Processing',
#    'receivingLocation': 'Natural Processing',
#    'cteDate': '2022-04-06',
#    'traceabilityLotCodeSourceLocation': 'Natural Processing',
#    'referenceDocumentTypeNumber': 'BOL 30453'},
#   'transformation': {'dataSubmitter': 'Natural Processing',
#    'oldTraceabilityLotCode': 'OO-4264',
#    'oldProductDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantityUsed': 1135,
#    'previousUnitOfMeasure': 'kg',
#    'traceabilityLotCode': 'SN-5576',
#    'traceabilityLotCodeSourceLocation': 'Natural Processing',
#    'cteDate': '2022-04-08',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantity': 634,
#    'unitOfMeasure': 'oz',
#    'referenceDocumentTypeNumber': 'BOL 27666'},
#   'shipping': {'dataSubmitter': 'Natural Processing',
#    'traceabilityLotCode': 'SN-5576',
#    'quantity': 634,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'subsequentLocation': 'Wholesome Operations',
#    'previousSourceLocation': 'Natural Processing',
#    'cteDate': '2022-04-08',
#    'traceabilityLotCodeSourceLocation': 'Natural Processing',
#    'referenceDocumentTypeNumber': 'BOL 32991'}},
#  {'receiving': {'dataSubmitter': 'Wholesome Operations',
#    'traceabilityLotCode': 'SN-5576',
#    'quantity': 634,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'previousSourceLocation': 'Natural Processing',
#    'receivingLocation': 'Wholesome Operations',
#    'cteDate': '2022-04-11',
#    'traceabilityLotCodeSourceLocation': 'Natural Processing',
#    'referenceDocumentTypeNumber': 'BOL 13924'},
#   'transformation': {'dataSubmitter': 'Wholesome Operations',
#    'oldTraceabilityLotCode': 'SN-5576',
#    'oldProductDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantityUsed': 741,
#    'previousUnitOfMeasure': 'oz',
#    'traceabilityLotCode': 'KF-9583',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Operations',
#    'cteDate': '2022-04-13',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'quantity': 605,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 31819'},
#   'shipping': {'dataSubmitter': 'Wholesome Operations',
#    'traceabilityLotCode': 'KF-9583',
#    'quantity': 605,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'subsequentLocation': 'Global Supply',
#    'previousSourceLocation': 'Wholesome Operations',
#    'cteDate': '2022-04-15',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Operations',
#    'referenceDocumentTypeNumber': 'BOL 28713'}},
#  {'receiving': {'dataSubmitter': 'Global Supply',
#    'traceabilityLotCode': 'KF-9583',
#    'quantity': 605,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'previousSourceLocation': 'Wholesome Operations',
#    'receivingLocation': 'Global Supply',
#    'cteDate': '2022-04-15',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Operations',
#    'referenceDocumentTypeNumber': 'BOL 41627'},
#   'shipping': {'dataSubmitter': 'Global Supply',
#    'traceabilityLotCode': 'KF-9583',
#    'quantity': 605,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'subsequentLocation': 'Best Trading',
#    'previousSourceLocation': 'Global Supply',
#    'cteDate': '2022-04-18',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Operations',
#    'referenceDocumentTypeNumber': 'BOL 32179'}},
#  {'receiving': {'dataSubmitter': 'Best Trading',
#    'traceabilityLotCode': 'KF-9583',
#    'quantity': 605,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'previousSourceLocation': 'Global Supply',
#    'receivingLocation': 'Best Trading',
#    'cteDate': '2022-04-20',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Operations',
#    'referenceDocumentTypeNumber': 'BOL 32453'},
#   'shipping': {'dataSubmitter': 'Best Trading',
#    'traceabilityLotCode': 'KF-9583',
#    'quantity': 605,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'subsequentLocation': 'Premium Bazaar',
#    'previousSourceLocation': 'Best Trading',
#    'cteDate': '2022-04-20',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Operations',
#    'referenceDocumentTypeNumber': 'BOL 30605'}},
#  {'receiving': {'dataSubmitter': 'Premium Bazaar',
#    'traceabilityLotCode': 'KF-9583',
#    'quantity': 605,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Sea Aquaculture clams, 26Dozen case',
#    'previousSourceLocation': 'Best Trading',
#    'receivingLocation': 'Premium Bazaar',
#    'cteDate': '2022-04-23',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Operations',
#    'referenceDocumentTypeNumber': 'BOL 26492'}},
#  {'harvesting': {'dataSubmitter': 'Misty Fields Farm',
#    'recipient': 'Misty Fields Farm',
#    'commodity': 'big beef tomato',
#    'quantity': 97,
#    'unitOfMeasure': 'g',
#    'farmName': 'Misty Fields Farm',
#    'fieldName': 'Rose Garden',
#    'containerName': 'n/a',
#    'cteDate': '2022-04-29',
#    'phoneNumber': '(062)266-9507'},
#   'cooling': {'dataSubmitter': 'Misty Fields Farm',
#    'recipient': 'Misty Fields Farm',
#    'commodity': 'big beef tomato',
#    'quantity': 97,
#    'unitOfMeasure': 'g',
#    'coolerLocation': 'Misty Fields Farm',
#    'cteDate': '2022-04-29',
#    'harvesterName': 'Misty Fields Farm',
#    'phoneNumber': '(062)266-9507'},
#   'initialPackaging': {'dataSubmitter': 'Misty Fields Farm',
#    'commodity': 'big beef tomato',
#    'dateFoodReceived': '2022-05-01',
#    'quantityReceived': 97,
#    'harvestingLocation': 'Misty Fields Farm',
#    'harvestedField': 'Rose Garden',
#    'harvestedContainer': 'n/a',
#    'harvestedPhoneNumber': '(062)266-9507',
#    'dateHarvested': '2022-04-29',
#    'coolingLocation': 'Misty Fields Farm',
#    'dateOfCooling': '2022-04-29',
#    'traceabilityLotCode': 'ZK-4960',
#    'productDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'quantity': 709,
#    'unitOfMeasure': 'g',
#    'packageType': 'Can',
#    'traceabilityLotCodeSourceLocation': 'Misty Fields Farm',
#    'cteDate': '2022-05-01',
#    'referenceDocumentTypeNumber': 'IP WO 11660'},
#   'shipping': {'dataSubmitter': 'Misty Fields Farm',
#    'traceabilityLotCode': 'ZK-4960',
#    'quantity': 709,
#    'unitOfMeasure': 'g',
#    'productDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'subsequentLocation': 'Pure Foods',
#    'previousSourceLocation': 'Misty Fields Farm',
#    'cteDate': '2022-05-03',
#    'traceabilityLotCodeSourceLocation': 'Misty Fields Farm',
#    'referenceDocumentTypeNumber': 'BOL 31379'}},
#  {'receiving': {'dataSubmitter': 'Pure Foods',
#    'traceabilityLotCode': 'ZK-4960',
#    'quantity': 709,
#    'unitOfMeasure': 'g',
#    'productDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'previousSourceLocation': 'Misty Fields Farm',
#    'receivingLocation': 'Pure Foods',
#    'cteDate': '2022-05-06',
#    'traceabilityLotCodeSourceLocation': 'Misty Fields Farm',
#    'referenceDocumentTypeNumber': 'BOL 28843'},
#   'transformation': {'dataSubmitter': 'Pure Foods',
#    'oldTraceabilityLotCode': 'ZK-4960',
#    'oldProductDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'quantityUsed': 1026,
#    'previousUnitOfMeasure': 'g',
#    'traceabilityLotCode': 'QQ-5574',
#    'traceabilityLotCodeSourceLocation': 'Pure Foods',
#    'cteDate': '2022-05-07',
#    'productDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'quantity': 949,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 26054'},
#   'shipping': {'dataSubmitter': 'Pure Foods',
#    'traceabilityLotCode': 'QQ-5574',
#    'quantity': 949,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'subsequentLocation': 'Reliable Distributors',
#    'previousSourceLocation': 'Pure Foods',
#    'cteDate': '2022-05-09',
#    'traceabilityLotCodeSourceLocation': 'Pure Foods',
#    'referenceDocumentTypeNumber': 'BOL 46741'}},
#  {'receiving': {'dataSubmitter': 'Reliable Distributors',
#    'traceabilityLotCode': 'QQ-5574',
#    'quantity': 949,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'previousSourceLocation': 'Pure Foods',
#    'receivingLocation': 'Reliable Distributors',
#    'cteDate': '2022-05-12',
#    'traceabilityLotCodeSourceLocation': 'Pure Foods',
#    'referenceDocumentTypeNumber': 'BOL 46491'},
#   'shipping': {'dataSubmitter': 'Reliable Distributors',
#    'traceabilityLotCode': 'QQ-5574',
#    'quantity': 949,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'subsequentLocation': 'Best Imports',
#    'previousSourceLocation': 'Reliable Distributors',
#    'cteDate': '2022-05-15',
#    'traceabilityLotCodeSourceLocation': 'Pure Foods',
#    'referenceDocumentTypeNumber': 'BOL 28184'}},
#  {'receiving': {'dataSubmitter': 'Best Imports',
#    'traceabilityLotCode': 'QQ-5574',
#    'quantity': 949,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Misty Fields Farm big beef tomato, 31lbs case',
#    'previousSourceLocation': 'Reliable Distributors',
#    'receivingLocation': 'Best Imports',
#    'cteDate': '2022-05-17',
#    'traceabilityLotCodeSourceLocation': 'Pure Foods',
#    'referenceDocumentTypeNumber': 'BOL 44403'}},
#  {'harvesting': {'dataSubmitter': 'Aqua Fishery',
#    'recipient': 'Aqua Fishery',
#    'commodity': 'clams',
#    'quantity': 845,
#    'unitOfMeasure': 'kg',
#    'farmName': 'Aqua Fishery',
#    'fieldName': 'n/a',
#    'containerName': 'Pond 7',
#    'cteDate': '2022-04-26',
#    'phoneNumber': '974-679-5169'},
#   'cooling': {'dataSubmitter': 'Aqua Fishery',
#    'recipient': 'Aqua Fishery',
#    'commodity': 'clams',
#    'quantity': 845,
#    'unitOfMeasure': 'kg',
#    'coolerLocation': 'Aqua Fishery',
#    'cteDate': '2022-04-26',
#    'harvesterName': 'Aqua Fishery',
#    'phoneNumber': '974-679-5169'},
#   'initialPackaging': {'dataSubmitter': 'Aqua Fishery',
#    'commodity': 'clams',
#    'dateFoodReceived': '2022-04-26',
#    'quantityReceived': 845,
#    'harvestingLocation': 'Aqua Fishery',
#    'harvestedField': 'n/a',
#    'harvestedContainer': 'Pond 7',
#    'harvestedPhoneNumber': '974-679-5169',
#    'dateHarvested': '2022-04-26',
#    'coolingLocation': 'Aqua Fishery',
#    'dateOfCooling': '2022-04-26',
#    'traceabilityLotCode': 'GE-7435',
#    'productDescription': 'Aqua Fishery clams, 44lbs case',
#    'quantity': 783,
#    'unitOfMeasure': 'kg',
#    'packageType': 'Bottle',
#    'traceabilityLotCodeSourceLocation': 'Aqua Fishery',
#    'cteDate': '2022-04-26',
#    'referenceDocumentTypeNumber': 'IP WO 21852'},
#   'shipping': {'dataSubmitter': 'Aqua Fishery',
#    'traceabilityLotCode': 'GE-7435',
#    'quantity': 783,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'Aqua Fishery clams, 44lbs case',
#    'subsequentLocation': 'Innovative Operations',
#    'previousSourceLocation': 'Aqua Fishery',
#    'cteDate': '2022-04-26',
#    'traceabilityLotCodeSourceLocation': 'Aqua Fishery',
#    'referenceDocumentTypeNumber': 'BOL 41700'}},
#  {'receiving': {'dataSubmitter': 'Innovative Operations',
#    'traceabilityLotCode': 'GE-7435',
#    'quantity': 783,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'Aqua Fishery clams, 44lbs case',
#    'previousSourceLocation': 'Aqua Fishery',
#    'receivingLocation': 'Innovative Operations',
#    'cteDate': '2022-04-28',
#    'traceabilityLotCodeSourceLocation': 'Aqua Fishery',
#    'referenceDocumentTypeNumber': 'BOL 37909'},
#   'transformation': {'dataSubmitter': 'Innovative Operations',
#    'oldTraceabilityLotCode': 'GE-7435',
#    'oldProductDescription': 'Aqua Fishery clams, 44lbs case',
#    'quantityUsed': 791,
#    'previousUnitOfMeasure': 'kg',
#    'traceabilityLotCode': 'QX-3904',
#    'traceabilityLotCodeSourceLocation': 'Innovative Operations',
#    'cteDate': '2022-04-29',
#    'productDescription': 'Aqua Fishery clams, 44lbs case',
#    'quantity': 1,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 34276'}},
#  {'transformation': {'dataSubmitter': 'Quality Solutions',
#    'oldTraceabilityLotCode': 'EY-0917',
#    'oldProductDescription': 'eggs',
#    'quantityUsed': 1567,
#    'previousUnitOfMeasure': 'kg',
#    'traceabilityLotCode': 'AE-0371',
#    'traceabilityLotCodeSourceLocation': 'Quality Solutions',
#    'cteDate': '2021-11-17',
#    'productDescription': 'eggs',
#    'quantity': 526,
#    'unitOfMeasure': 'oz',
#    'referenceDocumentTypeNumber': 'BOL 25727'},
#   'shipping': {'dataSubmitter': 'Quality Solutions',
#    'traceabilityLotCode': 'AE-0371',
#    'quantity': 526,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'eggs',
#    'subsequentLocation': 'Reliable Trade',
#    'previousSourceLocation': 'Quality Solutions',
#    'cteDate': '2021-11-20',
#    'traceabilityLotCodeSourceLocation': 'Quality Solutions',
#    'referenceDocumentTypeNumber': 'BOL 39525'}},
#  {'receiving': {'dataSubmitter': 'Reliable Trade',
#    'traceabilityLotCode': 'AE-0371',
#    'quantity': 526,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'eggs',
#    'previousSourceLocation': 'Quality Solutions',
#    'receivingLocation': 'Reliable Trade',
#    'cteDate': '2021-11-23',
#    'traceabilityLotCodeSourceLocation': 'Quality Solutions',
#    'referenceDocumentTypeNumber': 'BOL 14341'},
#   'shipping': {'dataSubmitter': 'Reliable Trade',
#    'traceabilityLotCode': 'AE-0371',
#    'quantity': 526,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'eggs',
#    'subsequentLocation': 'Gourmet Store',
#    'previousSourceLocation': 'Reliable Trade',
#    'cteDate': '2021-11-23',
#    'traceabilityLotCodeSourceLocation': 'Quality Solutions',
#    'referenceDocumentTypeNumber': 'BOL 46484'}},
#  {'receiving': {'dataSubmitter': 'Gourmet Store',
#    'traceabilityLotCode': 'AE-0371',
#    'quantity': 526,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'eggs',
#    'previousSourceLocation': 'Reliable Trade',
#    'receivingLocation': 'Gourmet Store',
#    'cteDate': '2021-11-24',
#    'traceabilityLotCodeSourceLocation': 'Quality Solutions',
#    'referenceDocumentTypeNumber': 'BOL 20062'}},
#  {'harvesting': {'dataSubmitter': 'Blue Fish Farm',
#    'recipient': 'Blue Fish Farm',
#    'commodity': 'clams',
#    'quantity': 273,
#    'unitOfMeasure': 'Dozen',
#    'farmName': 'Blue Fish Farm',
#    'fieldName': 'n/a',
#    'containerName': 'Cage 1',
#    'cteDate': '2023-03-15',
#    'phoneNumber': '(971)035-6379'},
#   'cooling': {'dataSubmitter': 'Blue Fish Farm',
#    'recipient': 'Blue Fish Farm',
#    'commodity': 'clams',
#    'quantity': 273,
#    'unitOfMeasure': 'Dozen',
#    'coolerLocation': 'Blue Fish Farm',
#    'cteDate': '2023-03-15',
#    'harvesterName': 'Blue Fish Farm',
#    'phoneNumber': '(971)035-6379'},
#   'initialPackaging': {'dataSubmitter': 'Blue Fish Farm',
#    'commodity': 'clams',
#    'dateFoodReceived': '2023-03-16',
#    'quantityReceived': 273,
#    'harvestingLocation': 'Blue Fish Farm',
#    'harvestedField': 'n/a',
#    'harvestedContainer': 'Cage 1',
#    'harvestedPhoneNumber': '(971)035-6379',
#    'dateHarvested': '2023-03-15',
#    'coolingLocation': 'Blue Fish Farm',
#    'dateOfCooling': '2023-03-15',
#    'traceabilityLotCode': 'PS-1038',
#    'productDescription': 'Blue Fish Farm clams, 14lbs case',
#    'quantity': 302,
#    'unitOfMeasure': 'Dozen',
#    'packageType': 'Bottle',
#    'traceabilityLotCodeSourceLocation': 'Blue Fish Farm',
#    'cteDate': '2023-03-16',
#    'referenceDocumentTypeNumber': 'IP WO 45579'},
#   'shipping': {'dataSubmitter': 'Blue Fish Farm',
#    'traceabilityLotCode': 'PS-1038',
#    'quantity': 302,
#    'unitOfMeasure': 'Dozen',
#    'productDescription': 'Blue Fish Farm clams, 14lbs case',
#    'subsequentLocation': 'Organic Manufacturing',
#    'previousSourceLocation': 'Blue Fish Farm',
#    'cteDate': '2023-03-18',
#    'traceabilityLotCodeSourceLocation': 'Blue Fish Farm',
#    'referenceDocumentTypeNumber': 'BOL 23423'}},
#  {'receiving': {'dataSubmitter': 'Organic Manufacturing',
#    'traceabilityLotCode': 'PS-1038',
#    'quantity': 302,
#    'unitOfMeasure': 'Dozen',
#    'productDescription': 'Blue Fish Farm clams, 14lbs case',
#    'previousSourceLocation': 'Blue Fish Farm',
#    'receivingLocation': 'Organic Manufacturing',
#    'cteDate': '2023-03-19',
#    'traceabilityLotCodeSourceLocation': 'Blue Fish Farm',
#    'referenceDocumentTypeNumber': 'BOL 42996'},
#   'transformation': {'dataSubmitter': 'Organic Manufacturing',
#    'oldTraceabilityLotCode': 'PS-1038',
#    'oldProductDescription': 'Blue Fish Farm clams, 14lbs case',
#    'quantityUsed': 1688,
#    'previousUnitOfMeasure': 'Dozen',
#    'traceabilityLotCode': 'QW-9034',
#    'traceabilityLotCodeSourceLocation': 'Organic Manufacturing',
#    'cteDate': '2023-03-21',
#    'productDescription': 'Blue Fish Farm clams, 14lbs case',
#    'quantity': 823,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 15625'},
#   'shipping': {'dataSubmitter': 'Organic Manufacturing',
#    'traceabilityLotCode': 'QW-9034',
#    'quantity': 823,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Blue Fish Farm clams, 14lbs case',
#    'subsequentLocation': 'Fresh Industries',
#    'previousSourceLocation': 'Organic Manufacturing',
#    'cteDate': '2023-03-22',
#    'traceabilityLotCodeSourceLocation': 'Organic Manufacturing',
#    'referenceDocumentTypeNumber': 'BOL 31609'}},
#  {'receiving': {'dataSubmitter': 'Fresh Industries',
#    'traceabilityLotCode': 'QW-9034',
#    'quantity': 823,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'Blue Fish Farm clams, 14lbs case',
#    'previousSourceLocation': 'Organic Manufacturing',
#    'receivingLocation': 'Fresh Industries',
#    'cteDate': '2023-03-23',
#    'traceabilityLotCodeSourceLocation': 'Organic Manufacturing',
#    'referenceDocumentTypeNumber': 'BOL 13638'},
#   'transformation': {'dataSubmitter': 'Fresh Industries',
#    'oldTraceabilityLotCode': 'QW-9034',
#    'oldProductDescription': 'Blue Fish Farm clams, 14lbs case',
#    'quantityUsed': 1577,
#    'previousUnitOfMeasure': 'cases',
#    'traceabilityLotCode': 'XZ-5003',
#    'traceabilityLotCodeSourceLocation': 'Fresh Industries',
#    'cteDate': '2023-03-24',
#    'productDescription': 'Blue Fish Farm clams, 14lbs case',
#    'quantity': 889,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 17698'}},
#  {'transformation': {'dataSubmitter': 'Wholesome Provisions',
#    'oldTraceabilityLotCode': 'ZV-6320',
#    'oldProductDescription': 'seafood salad',
#    'quantityUsed': 1433,
#    'previousUnitOfMeasure': 'oz',
#    'traceabilityLotCode': 'QG-0860',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Provisions',
#    'cteDate': '2021-02-19',
#    'productDescription': 'seafood salad',
#    'quantity': 520,
#    'unitOfMeasure': 'oz',
#    'referenceDocumentTypeNumber': 'BOL 31874'},
#   'shipping': {'dataSubmitter': 'Wholesome Provisions',
#    'traceabilityLotCode': 'QG-0860',
#    'quantity': 520,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'seafood salad',
#    'subsequentLocation': 'Healthy Cuisine',
#    'previousSourceLocation': 'Wholesome Provisions',
#    'cteDate': '2021-02-20',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Provisions',
#    'referenceDocumentTypeNumber': 'BOL 28667'}},
#  {'receiving': {'dataSubmitter': 'Healthy Cuisine',
#    'traceabilityLotCode': 'QG-0860',
#    'quantity': 520,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'seafood salad',
#    'previousSourceLocation': 'Wholesome Provisions',
#    'receivingLocation': 'Healthy Cuisine',
#    'cteDate': '2021-02-23',
#    'traceabilityLotCodeSourceLocation': 'Wholesome Provisions',
#    'referenceDocumentTypeNumber': 'BOL 25001'},
#   'transformation': {'dataSubmitter': 'Healthy Cuisine',
#    'oldTraceabilityLotCode': 'QG-0860',
#    'oldProductDescription': 'seafood salad',
#    'quantityUsed': 634,
#    'previousUnitOfMeasure': 'oz',
#    'traceabilityLotCode': 'YT-8593',
#    'traceabilityLotCodeSourceLocation': 'Healthy Cuisine',
#    'cteDate': '2021-02-24',
#    'productDescription': 'seafood salad',
#    'quantity': 501,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 49384'},
#   'shipping': {'dataSubmitter': 'Healthy Cuisine',
#    'traceabilityLotCode': 'YT-8593',
#    'quantity': 501,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'seafood salad',
#    'subsequentLocation': 'Trusted Services',
#    'previousSourceLocation': 'Healthy Cuisine',
#    'cteDate': '2021-02-25',
#    'traceabilityLotCodeSourceLocation': 'Healthy Cuisine',
#    'referenceDocumentTypeNumber': 'BOL 46613'}},
#  {'receiving': {'dataSubmitter': 'Trusted Services',
#    'traceabilityLotCode': 'YT-8593',
#    'quantity': 501,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'seafood salad',
#    'previousSourceLocation': 'Healthy Cuisine',
#    'receivingLocation': 'Trusted Services',
#    'cteDate': '2021-02-26',
#    'traceabilityLotCodeSourceLocation': 'Healthy Cuisine',
#    'referenceDocumentTypeNumber': 'BOL 23304'},
#   'shipping': {'dataSubmitter': 'Trusted Services',
#    'traceabilityLotCode': 'YT-8593',
#    'quantity': 501,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'seafood salad',
#    'subsequentLocation': 'Natural Market',
#    'previousSourceLocation': 'Trusted Services',
#    'cteDate': '2021-02-26',
#    'traceabilityLotCodeSourceLocation': 'Healthy Cuisine',
#    'referenceDocumentTypeNumber': 'BOL 30449'}},
#  {'receiving': {'dataSubmitter': 'Natural Market',
#    'traceabilityLotCode': 'YT-8593',
#    'quantity': 501,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'seafood salad',
#    'previousSourceLocation': 'Trusted Services',
#    'receivingLocation': 'Natural Market',
#    'cteDate': '2021-03-01',
#    'traceabilityLotCodeSourceLocation': 'Healthy Cuisine',
#    'referenceDocumentTypeNumber': 'BOL 40058'}},
#  {'harvesting': {'dataSubmitter': 'Breezy Pastures Farm',
#    'recipient': 'Fresh Packs',
#    'commodity': 'lychee',
#    'quantity': 727,
#    'unitOfMeasure': 'kg',
#    'farmName': 'Breezy Pastures Farm',
#    'fieldName': 'Walker Field',
#    'containerName': 'n/a',
#    'cteDate': '2022-11-12',
#    'phoneNumber': '700-363-7357'}},
#  {'cooling': {'dataSubmitter': 'Fresh Packs',
#    'recipient': 'Fresh Packs',
#    'commodity': 'lychee',
#    'quantity': 727,
#    'unitOfMeasure': 'kg',
#    'coolerLocation': 'Fresh Packs',
#    'cteDate': '2022-11-12',
#    'harvesterName': 'Breezy Pastures Farm',
#    'phoneNumber': '(605)981-6294'},
#   'initialPackaging': {'dataSubmitter': 'Fresh Packs',
#    'commodity': 'lychee',
#    'dateFoodReceived': '2022-11-12',
#    'quantityReceived': 727,
#    'harvestingLocation': 'Breezy Pastures Farm',
#    'harvestedField': 'Walker Field',
#    'harvestedContainer': 'n/a',
#    'harvestedPhoneNumber': '700-363-7357',
#    'dateHarvested': '2022-11-12',
#    'coolingLocation': 'Fresh Packs',
#    'dateOfCooling': '2022-11-12',
#    'traceabilityLotCode': 'AP-3262',
#    'productDescription': 'Breezy Pastures Farm lychee, 10kg case',
#    'quantity': 707,
#    'unitOfMeasure': 'kg',
#    'packageType': 'Box',
#    'traceabilityLotCodeSourceLocation': 'Fresh Packs',
#    'cteDate': '2022-11-12',
#    'referenceDocumentTypeNumber': 'IP WO 19719'},
#   'shipping': {'dataSubmitter': 'Fresh Packs',
#    'traceabilityLotCode': 'AP-3262',
#    'quantity': 707,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'Breezy Pastures Farm lychee, 10kg case',
#    'subsequentLocation': 'Premium Industries',
#    'previousSourceLocation': 'Fresh Packs',
#    'cteDate': '2022-11-12',
#    'traceabilityLotCodeSourceLocation': 'Fresh Packs',
#    'referenceDocumentTypeNumber': 'BOL 30379'}},
#  {'receiving': {'dataSubmitter': 'Premium Industries',
#    'traceabilityLotCode': 'AP-3262',
#    'quantity': 707,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'Breezy Pastures Farm lychee, 10kg case',
#    'previousSourceLocation': 'Fresh Packs',
#    'receivingLocation': 'Premium Industries',
#    'cteDate': '2022-11-12',
#    'traceabilityLotCodeSourceLocation': 'Fresh Packs',
#    'referenceDocumentTypeNumber': 'BOL 16281'},
#   'transformation': {'dataSubmitter': 'Premium Industries',
#    'oldTraceabilityLotCode': 'AP-3262',
#    'oldProductDescription': 'Breezy Pastures Farm lychee, 10kg case',
#    'quantityUsed': 1271,
#    'previousUnitOfMeasure': 'kg',
#    'traceabilityLotCode': 'AN-1519',
#    'traceabilityLotCodeSourceLocation': 'Premium Industries',
#    'cteDate': '2022-11-15',
#    'productDescription': 'Breezy Pastures Farm lychee, 10kg case',
#    'quantity': 179,
#    'unitOfMeasure': 'lbs',
#    'referenceDocumentTypeNumber': 'BOL 29793'},
#   'shipping': {'dataSubmitter': 'Premium Industries',
#    'traceabilityLotCode': 'AN-1519',
#    'quantity': 179,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Breezy Pastures Farm lychee, 10kg case',
#    'subsequentLocation': 'Organic Grocery',
#    'previousSourceLocation': 'Premium Industries',
#    'cteDate': '2022-11-17',
#    'traceabilityLotCodeSourceLocation': 'Premium Industries',
#    'referenceDocumentTypeNumber': 'BOL 30395'}},
#  {'receiving': {'dataSubmitter': 'Organic Grocery',
#    'traceabilityLotCode': 'AN-1519',
#    'quantity': 179,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Breezy Pastures Farm lychee, 10kg case',
#    'previousSourceLocation': 'Premium Industries',
#    'receivingLocation': 'Organic Grocery',
#    'cteDate': '2022-11-18',
#    'traceabilityLotCodeSourceLocation': 'Premium Industries',
#    'referenceDocumentTypeNumber': 'BOL 49701'}},
#  {'transformation': {'dataSubmitter': 'Pure Industries',
#    'oldTraceabilityLotCode': 'GA-9176',
#    'oldProductDescription': 'hazelnut',
#    'quantityUsed': 1205,
#    'previousUnitOfMeasure': 'oz',
#    'traceabilityLotCode': 'OG-7634',
#    'traceabilityLotCodeSourceLocation': 'Pure Industries',
#    'cteDate': '2020-07-18',
#    'productDescription': 'hazelnut',
#    'quantity': 212,
#    'unitOfMeasure': 'kg',
#    'referenceDocumentTypeNumber': 'BOL 12033'},
#   'shipping': {'dataSubmitter': 'Pure Industries',
#    'traceabilityLotCode': 'OG-7634',
#    'quantity': 212,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'hazelnut',
#    'subsequentLocation': 'Innovative Solutions',
#    'previousSourceLocation': 'Pure Industries',
#    'cteDate': '2020-07-18',
#    'traceabilityLotCodeSourceLocation': 'Pure Industries',
#    'referenceDocumentTypeNumber': 'BOL 32194'}},
#  {'receiving': {'dataSubmitter': 'Innovative Solutions',
#    'traceabilityLotCode': 'OG-7634',
#    'quantity': 212,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'hazelnut',
#    'previousSourceLocation': 'Pure Industries',
#    'receivingLocation': 'Innovative Solutions',
#    'cteDate': '2020-07-20',
#    'traceabilityLotCodeSourceLocation': 'Pure Industries',
#    'referenceDocumentTypeNumber': 'BOL 30545'},
#   'transformation': {'dataSubmitter': 'Innovative Solutions',
#    'oldTraceabilityLotCode': 'OG-7634',
#    'oldProductDescription': 'hazelnut',
#    'quantityUsed': 1775,
#    'previousUnitOfMeasure': 'kg',
#    'traceabilityLotCode': 'PY-8528',
#    'traceabilityLotCodeSourceLocation': 'Innovative Solutions',
#    'cteDate': '2020-07-23',
#    'productDescription': 'hazelnut',
#    'quantity': 665,
#    'unitOfMeasure': 'kg',
#    'referenceDocumentTypeNumber': 'BOL 28149'},
#   'shipping': {'dataSubmitter': 'Innovative Solutions',
#    'traceabilityLotCode': 'PY-8528',
#    'quantity': 665,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'hazelnut',
#    'subsequentLocation': 'Trusted Distributors',
#    'previousSourceLocation': 'Innovative Solutions',
#    'cteDate': '2020-07-26',
#    'traceabilityLotCodeSourceLocation': 'Innovative Solutions',
#    'referenceDocumentTypeNumber': 'BOL 14472'}},
#  {'receiving': {'dataSubmitter': 'Trusted Distributors',
#    'traceabilityLotCode': 'PY-8528',
#    'quantity': 665,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'hazelnut',
#    'previousSourceLocation': 'Innovative Solutions',
#    'receivingLocation': 'Trusted Distributors',
#    'cteDate': '2020-07-28',
#    'traceabilityLotCodeSourceLocation': 'Innovative Solutions',
#    'referenceDocumentTypeNumber': 'BOL 32468'},
#   'shipping': {'dataSubmitter': 'Trusted Distributors',
#    'traceabilityLotCode': 'PY-8528',
#    'quantity': 665,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'hazelnut',
#    'subsequentLocation': 'Organic Mart',
#    'previousSourceLocation': 'Trusted Distributors',
#    'cteDate': '2020-07-28',
#    'traceabilityLotCodeSourceLocation': 'Innovative Solutions',
#    'referenceDocumentTypeNumber': 'BOL 40365'}},
#  {'receiving': {'dataSubmitter': 'Organic Mart',
#    'traceabilityLotCode': 'PY-8528',
#    'quantity': 665,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'hazelnut',
#    'previousSourceLocation': 'Trusted Distributors',
#    'receivingLocation': 'Organic Mart',
#    'cteDate': '2020-07-29',
#    'traceabilityLotCodeSourceLocation': 'Innovative Solutions',
#    'referenceDocumentTypeNumber': 'BOL 43522'}},
#  {'firstLandBasedReceiving': {'dataSubmitter': 'Sea Maritime',
#    'traceabilityLotCode': 'OO-2267',
#    'productDescription': 'pollock',
#    'quantity': 726,
#    'unitOfMeasure': 'kg',
#    'harvestDateAndLocation': '2022-01-09 - 2022-01-13\nMajor Fishing Area 8\nCentral Pacific',
#    'traceabilityLotCodeSourceLocation': 'Sea Maritime',
#    'cteDate': '2022-01-15',
#    'referenceDocumentTypeNumber': 'Landing Record: 40061'},
#   'shipping': {'dataSubmitter': 'Sea Maritime',
#    'traceabilityLotCode': 'OO-2267',
#    'quantity': 726,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'pollock',
#    'subsequentLocation': 'Organic Products',
#    'previousSourceLocation': 'Sea Maritime',
#    'cteDate': '2022-01-17',
#    'traceabilityLotCodeSourceLocation': 'Sea Maritime',
#    'referenceDocumentTypeNumber': 'BOL 35798'}},
#  {'receiving': {'dataSubmitter': 'Organic Products',
#    'traceabilityLotCode': 'OO-2267',
#    'quantity': 726,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'pollock',
#    'previousSourceLocation': 'Sea Maritime',
#    'receivingLocation': 'Organic Products',
#    'cteDate': '2022-01-18',
#    'traceabilityLotCodeSourceLocation': 'Sea Maritime',
#    'referenceDocumentTypeNumber': 'BOL 33122'},
#   'transformation': {'dataSubmitter': 'Organic Products',
#    'oldTraceabilityLotCode': 'OO-2267',
#    'oldProductDescription': 'pollock',
#    'quantityUsed': 1205,
#    'previousUnitOfMeasure': 'kg',
#    'traceabilityLotCode': 'DG-5427',
#    'traceabilityLotCodeSourceLocation': 'Organic Products',
#    'cteDate': '2022-01-21',
#    'productDescription': 'pollock',
#    'quantity': 736,
#    'unitOfMeasure': 'lbs',
#    'referenceDocumentTypeNumber': 'BOL 28242'}},
#  {'firstLandBasedReceiving': {'dataSubmitter': 'Sea Mariscos',
#    'traceabilityLotCode': 'IC-3556',
#    'productDescription': 'clams',
#    'quantity': 565,
#    'unitOfMeasure': 'lb',
#    'harvestDateAndLocation': '2022-12-01 - 2022-12-10\nMajor Fishing Area 2\nSouthern Atlantic',
#    'traceabilityLotCodeSourceLocation': 'Sea Mariscos',
#    'cteDate': '2022-12-13',
#    'referenceDocumentTypeNumber': 'Landing Record: 35088'},
#   'shipping': {'dataSubmitter': 'Sea Mariscos',
#    'traceabilityLotCode': 'IC-3556',
#    'quantity': 565,
#    'unitOfMeasure': 'lb',
#    'productDescription': 'clams',
#    'subsequentLocation': 'Quality Operations',
#    'previousSourceLocation': 'Sea Mariscos',
#    'cteDate': '2022-12-13',
#    'traceabilityLotCodeSourceLocation': 'Sea Mariscos',
#    'referenceDocumentTypeNumber': 'BOL 26079'}},
#  {'receiving': {'dataSubmitter': 'Quality Operations',
#    'traceabilityLotCode': 'IC-3556',
#    'quantity': 565,
#    'unitOfMeasure': 'lb',
#    'productDescription': 'clams',
#    'previousSourceLocation': 'Sea Mariscos',
#    'receivingLocation': 'Quality Operations',
#    'cteDate': '2022-12-16',
#    'traceabilityLotCodeSourceLocation': 'Sea Mariscos',
#    'referenceDocumentTypeNumber': 'BOL 10558'},
#   'transformation': {'dataSubmitter': 'Quality Operations',
#    'oldTraceabilityLotCode': 'IC-3556',
#    'oldProductDescription': 'clams',
#    'quantityUsed': 142,
#    'previousUnitOfMeasure': 'lb',
#    'traceabilityLotCode': 'UQ-0907',
#    'traceabilityLotCodeSourceLocation': 'Quality Operations',
#    'cteDate': '2022-12-19',
#    'productDescription': 'clams',
#    'quantity': 64,
#    'unitOfMeasure': 'lbs',
#    'referenceDocumentTypeNumber': 'BOL 47984'},
#   'shipping': {'dataSubmitter': 'Quality Operations',
#    'traceabilityLotCode': 'UQ-0907',
#    'quantity': 64,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'clams',
#    'subsequentLocation': 'Natural Industries',
#    'previousSourceLocation': 'Quality Operations',
#    'cteDate': '2022-12-22',
#    'traceabilityLotCodeSourceLocation': 'Quality Operations',
#    'referenceDocumentTypeNumber': 'BOL 35230'}},
#  {'receiving': {'dataSubmitter': 'Natural Industries',
#    'traceabilityLotCode': 'UQ-0907',
#    'quantity': 64,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'clams',
#    'previousSourceLocation': 'Quality Operations',
#    'receivingLocation': 'Natural Industries',
#    'cteDate': '2022-12-23',
#    'traceabilityLotCodeSourceLocation': 'Quality Operations',
#    'referenceDocumentTypeNumber': 'BOL 23892'},
#   'transformation': {'dataSubmitter': 'Natural Industries',
#    'oldTraceabilityLotCode': 'UQ-0907',
#    'oldProductDescription': 'clams',
#    'quantityUsed': 1792,
#    'previousUnitOfMeasure': 'lbs',
#    'traceabilityLotCode': 'EM-2695',
#    'traceabilityLotCodeSourceLocation': 'Natural Industries',
#    'cteDate': '2022-12-25',
#    'productDescription': 'clams',
#    'quantity': 404,
#    'unitOfMeasure': 'lbs',
#    'referenceDocumentTypeNumber': 'BOL 11201'},
#   'shipping': {'dataSubmitter': 'Natural Industries',
#    'traceabilityLotCode': 'EM-2695',
#    'quantity': 404,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'clams',
#    'subsequentLocation': 'Innovative Kitchen',
#    'previousSourceLocation': 'Natural Industries',
#    'cteDate': '2022-12-27',
#    'traceabilityLotCodeSourceLocation': 'Natural Industries',
#    'referenceDocumentTypeNumber': 'BOL 18045'}},
#  {'receiving': {'dataSubmitter': 'Innovative Kitchen',
#    'traceabilityLotCode': 'EM-2695',
#    'quantity': 404,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'clams',
#    'previousSourceLocation': 'Natural Industries',
#    'receivingLocation': 'Innovative Kitchen',
#    'cteDate': '2022-12-28',
#    'traceabilityLotCodeSourceLocation': 'Natural Industries',
#    'referenceDocumentTypeNumber': 'BOL 42013'},
#   'transformation': {'dataSubmitter': 'Innovative Kitchen',
#    'oldTraceabilityLotCode': 'EM-2695',
#    'oldProductDescription': 'clams',
#    'quantityUsed': 685,
#    'previousUnitOfMeasure': 'lbs',
#    'traceabilityLotCode': 'BK-8075',
#    'traceabilityLotCodeSourceLocation': 'Innovative Kitchen',
#    'cteDate': '2022-12-31',
#    'productDescription': 'clams',
#    'quantity': 520,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 46630'},
#   'shipping': {'dataSubmitter': 'Innovative Kitchen',
#    'traceabilityLotCode': 'BK-8075',
#    'quantity': 520,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'clams',
#    'subsequentLocation': 'Premium Solutions',
#    'previousSourceLocation': 'Innovative Kitchen',
#    'cteDate': '2023-01-01',
#    'traceabilityLotCodeSourceLocation': 'Innovative Kitchen',
#    'referenceDocumentTypeNumber': 'BOL 39485'}},
#  {'receiving': {'dataSubmitter': 'Premium Solutions',
#    'traceabilityLotCode': 'BK-8075',
#    'quantity': 520,
#    'unitOfMeasure': 'cases',
#    'productDescription': 'clams',
#    'previousSourceLocation': 'Innovative Kitchen',
#    'receivingLocation': 'Premium Solutions',
#    'cteDate': '2023-01-03',
#    'traceabilityLotCodeSourceLocation': 'Innovative Kitchen',
#    'referenceDocumentTypeNumber': 'BOL 13030'},
#   'transformation': {'dataSubmitter': 'Premium Solutions',
#    'oldTraceabilityLotCode': 'BK-8075',
#    'oldProductDescription': 'clams',
#    'quantityUsed': 1569,
#    'previousUnitOfMeasure': 'cases',
#    'traceabilityLotCode': 'HW-6087',
#    'traceabilityLotCodeSourceLocation': 'Premium Solutions',
#    'cteDate': '2023-01-04',
#    'productDescription': 'clams',
#    'quantity': 494,
#    'unitOfMeasure': 'kg',
#    'referenceDocumentTypeNumber': 'BOL 20878'},
#   'shipping': {'dataSubmitter': 'Premium Solutions',
#    'traceabilityLotCode': 'HW-6087',
#    'quantity': 494,
#    'unitOfMeasure': 'kg',
#    'productDescription': 'clams',
#    'subsequentLocation': 'Fresh Shop',
#    'previousSourceLocation': 'Premium Solutions',
#    'cteDate': '2023-01-06',
#    'traceabilityLotCodeSourceLocation': 'Premium Solutions',
#    'referenceDocumentTypeNumber': 'BOL 13068'}},
# ...
#    'oldProductDescription': 'Marine Aquaculture barracuda, 2lbs case',
#    'quantityUsed': 1889,
#    'previousUnitOfMeasure': 'g',
#    'traceabilityLotCode': 'OX-9195',
#    'traceabilityLotCodeSourceLocation': 'Fresh Operations',
#    'cteDate': '2023-02-15',
#    'productDescription': 'Marine Aquaculture barracuda, 2lbs case',
#    'quantity': 959,
#    'unitOfMeasure': 'lbs',
#    'referenceDocumentTypeNumber': 'BOL 28863'},
#   'shipping': {'dataSubmitter': 'Fresh Operations',
#    'traceabilityLotCode': 'OX-9195',
#    'quantity': 959,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Marine Aquaculture barracuda, 2lbs case',
#    'subsequentLocation': 'Global Manufacturing',
#    'previousSourceLocation': 'Fresh Operations',
#    'cteDate': '2023-02-18',
#    'traceabilityLotCodeSourceLocation': 'Fresh Operations',
#    'referenceDocumentTypeNumber': 'BOL 31403'}},
#  {'receiving': {'dataSubmitter': 'Global Manufacturing',
#    'traceabilityLotCode': 'OX-9195',
#    'quantity': 959,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Marine Aquaculture barracuda, 2lbs case',
#    'previousSourceLocation': 'Fresh Operations',
#    'receivingLocation': 'Global Manufacturing',
#    'cteDate': '2023-02-21',
#    'traceabilityLotCodeSourceLocation': 'Fresh Operations',
#    'referenceDocumentTypeNumber': 'BOL 46577'},
#   'transformation': {'dataSubmitter': 'Global Manufacturing',
#    'oldTraceabilityLotCode': 'OX-9195',
#    'oldProductDescription': 'Marine Aquaculture barracuda, 2lbs case',
#    'quantityUsed': 184,
#    'previousUnitOfMeasure': 'lbs',
#    'traceabilityLotCode': 'CX-8002',
#    'traceabilityLotCodeSourceLocation': 'Global Manufacturing',
#    'cteDate': '2023-02-24',
#    'productDescription': 'Marine Aquaculture barracuda, 2lbs case',
#    'quantity': 175,
#    'unitOfMeasure': 'oz',
#    'referenceDocumentTypeNumber': 'BOL 25294'}},
#  {'harvesting': {'dataSubmitter': 'Breezy Grove Farm',
#    'recipient': 'Breezy Grove Farm',
#    'commodity': 'chicory',
#    'quantity': 165,
#    'unitOfMeasure': 'lbs',
#    'farmName': 'Breezy Grove Farm',
#    'fieldName': 'Field G-20',
#    'containerName': 'n/a',
#    'cteDate': '2022-05-24',
#    'phoneNumber': '(887)919-6806'},
#   'cooling': {'dataSubmitter': 'Breezy Grove Farm',
#    'recipient': 'Breezy Grove Farm',
#    'commodity': 'chicory',
#    'quantity': 165,
#    'unitOfMeasure': 'lbs',
#    'coolerLocation': 'Breezy Grove Farm',
#    'cteDate': '2022-05-24',
#    'harvesterName': 'Breezy Grove Farm',
#    'phoneNumber': '(887)919-6806'},
#   'initialPackaging': {'dataSubmitter': 'Breezy Grove Farm',
#    'commodity': 'chicory',
#    'dateFoodReceived': '2022-05-27',
#    'quantityReceived': 165,
#    'harvestingLocation': 'Breezy Grove Farm',
#    'harvestedField': 'Field G-20',
#    'harvestedContainer': 'n/a',
#    'harvestedPhoneNumber': '(887)919-6806',
#    'dateHarvested': '2022-05-24',
#    'coolingLocation': 'Breezy Grove Farm',
#    'dateOfCooling': '2022-05-24',
#    'traceabilityLotCode': 'XI-6819',
#    'productDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'quantity': 454,
#    'unitOfMeasure': 'lbs',
#    'packageType': 'Pouch',
#    'traceabilityLotCodeSourceLocation': 'Breezy Grove Farm',
#    'cteDate': '2022-05-27',
#    'referenceDocumentTypeNumber': 'IP WO 44351'},
#   'shipping': {'dataSubmitter': 'Breezy Grove Farm',
#    'traceabilityLotCode': 'XI-6819',
#    'quantity': 454,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'subsequentLocation': 'Pure Manufacturing',
#    'previousSourceLocation': 'Breezy Grove Farm',
#    'cteDate': '2022-05-27',
#    'traceabilityLotCodeSourceLocation': 'Breezy Grove Farm',
#    'referenceDocumentTypeNumber': 'BOL 30494'}},
#  {'receiving': {'dataSubmitter': 'Pure Manufacturing',
#    'traceabilityLotCode': 'XI-6819',
#    'quantity': 454,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'previousSourceLocation': 'Breezy Grove Farm',
#    'receivingLocation': 'Pure Manufacturing',
#    'cteDate': '2022-05-27',
#    'traceabilityLotCodeSourceLocation': 'Breezy Grove Farm',
#    'referenceDocumentTypeNumber': 'BOL 44924'},
#   'transformation': {'dataSubmitter': 'Pure Manufacturing',
#    'oldTraceabilityLotCode': 'XI-6819',
#    'oldProductDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'quantityUsed': 1292,
#    'previousUnitOfMeasure': 'lbs',
#    'traceabilityLotCode': 'ZH-4843',
#    'traceabilityLotCodeSourceLocation': 'Pure Manufacturing',
#    'cteDate': '2022-05-28',
#    'productDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'quantity': 296,
#    'unitOfMeasure': 'oz',
#    'referenceDocumentTypeNumber': 'BOL 49172'},
#   'shipping': {'dataSubmitter': 'Pure Manufacturing',
#    'traceabilityLotCode': 'ZH-4843',
#    'quantity': 296,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'subsequentLocation': 'Trusted Exim',
#    'previousSourceLocation': 'Pure Manufacturing',
#    'cteDate': '2022-05-30',
#    'traceabilityLotCodeSourceLocation': 'Pure Manufacturing',
#    'referenceDocumentTypeNumber': 'BOL 49186'}},
#  {'receiving': {'dataSubmitter': 'Trusted Exim',
#    'traceabilityLotCode': 'ZH-4843',
#    'quantity': 296,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'previousSourceLocation': 'Pure Manufacturing',
#    'receivingLocation': 'Trusted Exim',
#    'cteDate': '2022-05-31',
#    'traceabilityLotCodeSourceLocation': 'Pure Manufacturing',
#    'referenceDocumentTypeNumber': 'BOL 21758'},
#   'shipping': {'dataSubmitter': 'Trusted Exim',
#    'traceabilityLotCode': 'ZH-4843',
#    'quantity': 296,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'subsequentLocation': 'Tasty Outlet',
#    'previousSourceLocation': 'Trusted Exim',
#    'cteDate': '2022-05-31',
#    'traceabilityLotCodeSourceLocation': 'Pure Manufacturing',
#    'referenceDocumentTypeNumber': 'BOL 12147'}},
#  {'receiving': {'dataSubmitter': 'Tasty Outlet',
#    'traceabilityLotCode': 'ZH-4843',
#    'quantity': 296,
#    'unitOfMeasure': 'oz',
#    'productDescription': 'Breezy Grove Farm chicory, 23Dozen case',
#    'previousSourceLocation': 'Trusted Exim',
#    'receivingLocation': 'Tasty Outlet',
#    'cteDate': '2022-06-03',
#    'traceabilityLotCodeSourceLocation': 'Pure Manufacturing',
#    'referenceDocumentTypeNumber': 'BOL 19270'}},
#  {'harvesting': {'dataSubmitter': 'Nautical Fish Haven',
#    'recipient': 'Nautical Fish Haven',
#    'commodity': 'lobster',
#    'quantity': 594,
#    'unitOfMeasure': 'lbs',
#    'farmName': 'Nautical Fish Haven',
#    'fieldName': 'n/a',
#    'containerName': 'Cage 10',
#    'cteDate': '2022-08-14',
#    'phoneNumber': '025-151-3161'},
#   'cooling': {'dataSubmitter': 'Nautical Fish Haven',
#    'recipient': 'Nautical Fish Haven',
#    'commodity': 'lobster',
#    'quantity': 594,
#    'unitOfMeasure': 'lbs',
#    'coolerLocation': 'Nautical Fish Haven',
#    'cteDate': '2022-08-14',
#    'harvesterName': 'Nautical Fish Haven',
#    'phoneNumber': '025-151-3161'},
#   'initialPackaging': {'dataSubmitter': 'Nautical Fish Haven',
#    'commodity': 'lobster',
#    'dateFoodReceived': '2022-08-15',
#    'quantityReceived': 594,
#    'harvestingLocation': 'Nautical Fish Haven',
#    'harvestedField': 'n/a',
#    'harvestedContainer': 'Cage 10',
#    'harvestedPhoneNumber': '025-151-3161',
#    'dateHarvested': '2022-08-14',
#    'coolingLocation': 'Nautical Fish Haven',
#    'dateOfCooling': '2022-08-14',
#    'traceabilityLotCode': 'DU-9535',
#    'productDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'quantity': 922,
#    'unitOfMeasure': 'lbs',
#    'packageType': 'Can',
#    'traceabilityLotCodeSourceLocation': 'Nautical Fish Haven',
#    'cteDate': '2022-08-15',
#    'referenceDocumentTypeNumber': 'IP WO 20738'},
#   'shipping': {'dataSubmitter': 'Nautical Fish Haven',
#    'traceabilityLotCode': 'DU-9535',
#    'quantity': 922,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'subsequentLocation': 'Organic Manufacturing',
#    'previousSourceLocation': 'Nautical Fish Haven',
#    'cteDate': '2022-08-15',
#    'traceabilityLotCodeSourceLocation': 'Nautical Fish Haven',
#    'referenceDocumentTypeNumber': 'BOL 43487'}},
#  {'receiving': {'dataSubmitter': 'Organic Manufacturing',
#    'traceabilityLotCode': 'DU-9535',
#    'quantity': 922,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'previousSourceLocation': 'Nautical Fish Haven',
#    'receivingLocation': 'Organic Manufacturing',
#    'cteDate': '2022-08-17',
#    'traceabilityLotCodeSourceLocation': 'Nautical Fish Haven',
#    'referenceDocumentTypeNumber': 'BOL 32514'},
#   'transformation': {'dataSubmitter': 'Organic Manufacturing',
#    'oldTraceabilityLotCode': 'DU-9535',
#    'oldProductDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'quantityUsed': 1150,
#    'previousUnitOfMeasure': 'lbs',
#    'traceabilityLotCode': 'UH-0116',
#    'traceabilityLotCodeSourceLocation': 'Organic Manufacturing',
#    'cteDate': '2022-08-19',
#    'productDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'quantity': 871,
#    'unitOfMeasure': 'lbs',
#    'referenceDocumentTypeNumber': 'BOL 13256'},
#   'shipping': {'dataSubmitter': 'Organic Manufacturing',
#    'traceabilityLotCode': 'UH-0116',
#    'quantity': 871,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'subsequentLocation': 'Healthy Operations',
#    'previousSourceLocation': 'Organic Manufacturing',
#    'cteDate': '2022-08-21',
#    'traceabilityLotCodeSourceLocation': 'Organic Manufacturing',
#    'referenceDocumentTypeNumber': 'BOL 25949'}},
#  {'receiving': {'dataSubmitter': 'Healthy Operations',
#    'traceabilityLotCode': 'UH-0116',
#    'quantity': 871,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'previousSourceLocation': 'Organic Manufacturing',
#    'receivingLocation': 'Healthy Operations',
#    'cteDate': '2022-08-23',
#    'traceabilityLotCodeSourceLocation': 'Organic Manufacturing',
#    'referenceDocumentTypeNumber': 'BOL 29730'},
#   'transformation': {'dataSubmitter': 'Healthy Operations',
#    'oldTraceabilityLotCode': 'UH-0116',
#    'oldProductDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'quantityUsed': 1735,
#    'previousUnitOfMeasure': 'lbs',
#    'traceabilityLotCode': 'CL-2764',
#    'traceabilityLotCodeSourceLocation': 'Healthy Operations',
#    'cteDate': '2022-08-25',
#    'productDescription': 'Nautical Fish Haven lobster, 33kg case',
#    'quantity': 552,
#    'unitOfMeasure': 'cases',
#    'referenceDocumentTypeNumber': 'BOL 37214'}},
#  {'harvesting': {'dataSubmitter': 'Lucky Orchard Farm',
#    'recipient': 'Bio Packs',
#    'commodity': 'honeydew',
#    'quantity': 862,
#    'unitOfMeasure': 'g',
#    'farmName': 'Lucky Orchard Farm',
#    'fieldName': 'Walker Field',
#    'containerName': 'n/a',
#    'cteDate': '2022-01-02',
#    'phoneNumber': '223-104-2228'}},
#  {'cooling': {'dataSubmitter': 'Bio Packs',
#    'recipient': 'Bio Packs',
#    'commodity': 'honeydew',
#    'quantity': 862,
#    'unitOfMeasure': 'g',
#    'coolerLocation': 'Bio Packs',
#    'cteDate': '2022-01-02',
#    'harvesterName': 'Lucky Orchard Farm',
#    'phoneNumber': '7897166593'},
#   'initialPackaging': {'dataSubmitter': 'Bio Packs',
#    'commodity': 'honeydew',
#    'dateFoodReceived': '2022-01-04',
#    'quantityReceived': 862,
#    'harvestingLocation': 'Lucky Orchard Farm',
#    'harvestedField': 'Walker Field',
#    'harvestedContainer': 'n/a',
#    'harvestedPhoneNumber': '223-104-2228',
#    'dateHarvested': '2022-01-02',
#    'coolingLocation': 'Bio Packs',
#    'dateOfCooling': '2022-01-02',
#    'traceabilityLotCode': 'WB-8914',
#    'productDescription': 'Lucky Orchard Farm honeydew, 9Dozen case',
#    'quantity': 468,
#    'unitOfMeasure': 'g',
#    'packageType': 'Crate',
#    'traceabilityLotCodeSourceLocation': 'Bio Packs',
#    'cteDate': '2022-01-04',
#    'referenceDocumentTypeNumber': 'IP WO 32681'},
#   'shipping': {'dataSubmitter': 'Bio Packs',
#    'traceabilityLotCode': 'WB-8914',
#    'quantity': 468,
#    'unitOfMeasure': 'g',
#    'productDescription': 'Lucky Orchard Farm honeydew, 9Dozen case',
#    'subsequentLocation': 'Organic Operations',
#    'previousSourceLocation': 'Bio Packs',
#    'cteDate': '2022-01-04',
#    'traceabilityLotCodeSourceLocation': 'Bio Packs',
#    'referenceDocumentTypeNumber': 'BOL 32883'}},
#  {'receiving': {'dataSubmitter': 'Organic Operations',
#    'traceabilityLotCode': 'WB-8914',
#    'quantity': 468,
#    'unitOfMeasure': 'g',
#    'productDescription': 'Lucky Orchard Farm honeydew, 9Dozen case',
#    'previousSourceLocation': 'Bio Packs',
#    'receivingLocation': 'Organic Operations',
#    'cteDate': '2022-01-06',
#    'traceabilityLotCodeSourceLocation': 'Bio Packs',
#    'referenceDocumentTypeNumber': 'BOL 18661'},
#   'transformation': {'dataSubmitter': 'Organic Operations',
#    'oldTraceabilityLotCode': 'WB-8914',
#    'oldProductDescription': 'Lucky Orchard Farm honeydew, 9Dozen case',
#    'quantityUsed': 908,
#    'previousUnitOfMeasure': 'g',
#    'traceabilityLotCode': 'AJ-4170',
#    'traceabilityLotCodeSourceLocation': 'Organic Operations',
#    'cteDate': '2022-01-09',
#    'productDescription': 'Lucky Orchard Farm honeydew, 9Dozen case',
#    'quantity': 481,
#    'unitOfMeasure': 'lbs',
#    'referenceDocumentTypeNumber': 'BOL 22706'},
#   'shipping': {'dataSubmitter': 'Organic Operations',
#    'traceabilityLotCode': 'AJ-4170',
#    'quantity': 481,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Lucky Orchard Farm honeydew, 9Dozen case',
#    'subsequentLocation': 'Wholesome Market',
#    'previousSourceLocation': 'Organic Operations',
#    'cteDate': '2022-01-12',
#    'traceabilityLotCodeSourceLocation': 'Organic Operations',
#    'referenceDocumentTypeNumber': 'BOL 13078'}},
#  {'receiving': {'dataSubmitter': 'Wholesome Market',
#    'traceabilityLotCode': 'AJ-4170',
#    'quantity': 481,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Lucky Orchard Farm honeydew, 9Dozen case',
#    'previousSourceLocation': 'Organic Operations',
#    'receivingLocation': 'Wholesome Market',
#    'cteDate': '2022-01-13',
#    'traceabilityLotCodeSourceLocation': 'Organic Operations',
#    'referenceDocumentTypeNumber': 'BOL 18545'}},
#  {'harvesting': {'dataSubmitter': 'Peaceful Harvest Farm',
#    'recipient': 'Peaceful Harvest Farm',
#    'commodity': 'cilantro',
#    'quantity': 621,
#    'unitOfMeasure': 'lbs',
#    'farmName': 'Peaceful Harvest Farm',
#    'fieldName': 'Field C-10',
#    'containerName': 'n/a',
#    'cteDate': '2022-05-04',
#    'phoneNumber': '602-322-2654'},
#   'cooling': {'dataSubmitter': 'Peaceful Harvest Farm',
#    'recipient': 'Peaceful Harvest Farm',
#    'commodity': 'cilantro',
#    'quantity': 621,
#    'unitOfMeasure': 'lbs',
#    'coolerLocation': 'Peaceful Harvest Farm',
#    'cteDate': '2022-05-04',
#    'harvesterName': 'Peaceful Harvest Farm',
#    'phoneNumber': '602-322-2654'},
#   'initialPackaging': {'dataSubmitter': 'Peaceful Harvest Farm',
#    'commodity': 'cilantro',
#    'dateFoodReceived': '2022-05-05',
#    'quantityReceived': 621,
#    'harvestingLocation': 'Peaceful Harvest Farm',
#    'harvestedField': 'Field C-10',
#    'harvestedContainer': 'n/a',
#    'harvestedPhoneNumber': '602-322-2654',
#    'dateHarvested': '2022-05-04',
#    'coolingLocation': 'Peaceful Harvest Farm',
#    'dateOfCooling': '2022-05-04',
#    'traceabilityLotCode': 'DX-0856',
#    'productDescription': 'Peaceful Harvest Farm cilantro, 36Dozen case',
#    'quantity': 779,
#    'unitOfMeasure': 'lbs',
#    'packageType': 'Bottle',
#    'traceabilityLotCodeSourceLocation': 'Peaceful Harvest Farm',
#    'cteDate': '2022-05-05',
#    'referenceDocumentTypeNumber': 'IP WO 28551'},
#   'shipping': {'dataSubmitter': 'Peaceful Harvest Farm',
#    'traceabilityLotCode': 'DX-0856',
#    'quantity': 779,
#    'unitOfMeasure': 'lbs',
#    'productDescription': 'Peaceful Harvest Farm cilantro, 36Dozen case',
#    'subsequentLocation': 'Healthy Manufacturing',
#    'previousSourceLocation': 'Peaceful Harvest Farm',
#    'cteDate': '2022-05-08',
#    'traceabilityLotCodeSourceLocation': 'Peaceful Harvest Farm',
#    'referenceDocumentTypeNumber': 'BOL 26383'}},
#  ...]
